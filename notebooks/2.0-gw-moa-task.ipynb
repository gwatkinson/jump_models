# %% [markdown]
# # Create MOA datasets

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Tests

# %%
import logging
import os
import os.path as osp
import shutil
from pathlib import Path
from typing import Any, Callable, Dict, List, Optional

import numpy as np
import pandas as pd
import seaborn as sns
import torch
import torch.nn as nn
import yaml
from lightning import LightningDataModule
from lightning.pytorch import Trainer
from lightning.pytorch.loggers import WandbLogger
from omegaconf import DictConfig, OmegaConf
from torch.utils.data import DataLoader, Dataset
from torchmetrics import MetricCollection
from torchmetrics.classification import MulticlassAccuracy

from src.eval.moa.datamodule import JumpMOADataModule
from src.eval.moa.module import JumpMOAImageModule
from src.modules.collate_fn import image_graph_label_collate_function, label_graph_collate_function
from src.modules.compound_transforms import DGLPretrainedFromSmiles
from src.modules.images.timm_pretrained import CNNEncoder
from src.modules.molecules.dgllife_gin import GINPretrainedWithLinearHead

# from src.modules.transforms import DefaultJUMPTransform
from src.splitters import StratifiedSplitter
from src.utils.io import download_and_extract_zip, load_image_paths_to_array

# %%
for i in range(1, 4):
    if not Path(f"../cpjump{i}/jump/").exists():
        print(f"Mounting cpjump{i}...")
        os.system(f"sshfs bioclust:/projects/cpjump{i}/ ../cpjump{i}")
    else:
        print(f"cpjump{i} already mounted.")
# Out:
# Mounting cpjump1...
# Mounting cpjump2...
# Mounting cpjump3...

# %%
metadata_path = "../cpjump1/jump/metadata"
load_data_path = "../cpjump1/jump/load_data"

# %%
os.listdir(metadata_path)
# Out:
# ['compound.csv.gz',
#  'crispr.csv.gz',
#  'microscope_config.csv',
#  'microscope_filter.csv',
#  'orf.csv.gz',
#  'plate.csv.gz',
#  'README.md',
#  'well.csv.gz',
#  'compound.csv',
#  'crispr.csv',
#  'orf.csv',
#  'plate.csv',
#  'well.csv',
#  'complete_metadata.csv',
#  'resolution.csv',
#  'JUMP-Target-1_compound_metadata.tsv',
#  'JUMP-Target-1_compound_platemap.tsv',
#  'JUMP-Target-1_crispr_metadata.tsv',
#  'JUMP-Target-1_crispr_platemap.tsv',
#  'JUMP-Target-1_orf_metadata.tsv',
#  'JUMP-Target-1_orf_platemap.tsv',
#  'JUMP-Target-2_compound_metadata.tsv',
#  'JUMP-Target-2_compound_platemap.tsv',
#  'JUMP-MOA_compound_metadata.tsv',
#  'local_metadata.csv']

# %%
load_df = pd.read_parquet(osp.join(load_data_path, "final"))

# %%
load_df
# Out:
#         Metadata_Source              Metadata_Batch     Metadata_Plate  \
# 0             source_10  2021_05_31_U2OS_48_hr_run1  Dest210531-152149
# 1             source_10  2021_05_31_U2OS_48_hr_run1  Dest210531-152149
# 2             source_10  2021_05_31_U2OS_48_hr_run1  Dest210531-152149
# 3             source_10  2021_05_31_U2OS_48_hr_run1  Dest210531-152149
# 4             source_10  2021_05_31_U2OS_48_hr_run1  Dest210531-152149
# ...                 ...                         ...                ...
# 5121195        source_9              20211103-Run16         GR00004421
# 5121196        source_9              20211103-Run16         GR00004421
# 5121197        source_9              20211103-Run16         GR00004421
# 5121198        source_9              20211103-Run16         GR00004421
# 5121199        source_9              20211103-Run16         GR00004421
#
#         Metadata_Well  Metadata_Site  \
# 0                 A01              1
# 1                 A01              3
# 2                 A01              6
# 3                 A02              1
# 4                 A02              2
# ...               ...            ...
# 5121195           Z47              3
# 5121196           Z47              4
# 5121197           Z48              1
# 5121198           Z48              2
# 5121199           Z48              3
#
#                                           FileName_OrigAGP  \
# 0        /projects/cpjump3/jump/images/source_10/2021_0...
# 1        /projects/cpjump3/jump/images/source_10/2021_0...
# 2        /projects/cpjump3/jump/images/source_10/2021_0...
# 3        /projects/cpjump3/jump/images/source_10/2021_0...
# 4        /projects/cpjump3/jump/images/source_10/2021_0...
# ...                                
projects/cpjump3/jump/images/source_10/2021_0...
# ...                                                    ...
# 5121195  /projects/cpjump1/jump/images/source_9/2021110...
# 5121196  /projects/cpjump1/jump/images/source_9/2021110...
# 5121197  /projects/cpjump1/jump/images/source_9/2021110...
# 5121198  /projects/cpjump1/jump/images/source_9/2021110...
# 5121199  /projects/cpjump1/jump/images/source_9/2021110...
#
# [5121200 rows x 10 columns]

# %% [markdown]
# ## Creating the dataset

# %%
moa = pd.read_csv(
    osp.join(metadata_path, "JUMP-MOA_compound_metadata.tsv"),
    sep="\t",
    usecols=["smiles", "InChIKey", "moa", "pert_type"],
)

# %%
meta = pd.read_csv(osp.join(metadata_path, "local_metadata.csv"))

# %%
compounds = pd.read_csv(osp.join(metadata_path, "compound.csv"))

# %%
meta
# Out:
#        Metadata_Source   Metadata_Batch Metadata_Plate Metadata_PlateType  \
# 0             source_1  Batch1_20221004       UL001641           COMPOUND
# 1             source_1  Batch1_20221004       UL001641           COMPOUND
# 2             source_1  Batch1_20221004       UL001641           COMPOUND
# 3             source_1  Batch1_20221004       UL001641           COMPOUND
# 4             source_1  Batch1_20221004       UL001641           COMPOUND
# ...                ...              ...            ...                ...
# 861157        source_9   20211103-Run16     GR00004421           COMPOUND
# 861158        source_9   20211103-Run16     GR00004421           COMPOUND
# 861159        source_9   20211103-Run16     GR00004421           COMPOUND
# 861160        source_9   20211103-Run16     GR00004421           COMPOUND
# 861161        source_9   20211103-Run16     GR00004421           COMPOUND
#
#        Metadata_Well Metadata_JCP2022            Metadata_InChIKey  \
# 0                A02   JCP2022_033924  IAZDPXIOMUYVGZ-UHFFFAOYSA-N
# 1                A03   JCP2022_085227  SRVFFFJZQVENJC-UHFFFAOYSA-N
# 2                A04   JCP2022_033924  IAZDPXIOMUYVGZ-UHFFFAOYSA-N
# 3                A05   JCP2022_036592  IPPYTNWGGOIMDZ-UHFFFAOYSA-N
# 4                A06   JCP2022_071885  PYZMXVUWLLQNEP-UHFFFAOYSA-N
# ...              ...              ...                          ...
# 861157           Z44   JCP2022_999999                          NaN
# 861158           Z45   JCP2022_999999                          NaN
# 861159           Z46   JCP2022_999999                          NaN
# 861160           Z47   JCP2022_033924  IAZDPXIOMUYVGZ-UHFFFAOYSA-N
# 861161           Z48   JCP2022_037716  IVUGFMLRJOCGAS-UHFFFAOYSA-N
#
#                                            Metadata_InChI  \
# 0                         InChI=1S/C2H6OS/c1-4(2)3/h1-2H3
# 1       InChI=1S/C17H30N2O5/c1-6-23-17(22)14-13(24-14)...
# 2                         InChI=1S/C2H6OS/c1-4(2)3/h1-2H3
# 3       InChI=1S/C17H12ClF3N4O2/c1-24(15-13(18)6-9(7-2...
# 4       InChI=1S/C10H7ClN4/c11-9-3-1-2-8(4-9)6-15-7-13...
# ...                                                   ...
# 861157                                                NaN
# 861158                                                NaN
# 861159                                                NaN
# 861160                    InChI=1S/C2H6OS/c1-4(2)3/h1-2H3
# 861161  InChI=1S/C28H21N7OS/c1-17-15-24(37-16-17)25-20...
#
#         Metadata_Sites_Per_Well           trt
# 0                             4  compound_neg
# 1                             4  compound_pos
# 2                             4  compound_neg
# 3                             4  compound_trt
# 4                             4  compound_trt
# ...                         ...           ...
# 861157                        4  compound_trt
# 861158                        4  compound_trt
# 861159                        4  compound_trt
# 861160                        4  compound_neg
# 861161                        4  compound_pos
#
# [861162 rows x 10 columns]

# %%
jump_moa = moa.dropna(subset=["InChIKey", "moa"]).merge(
    compounds, left_on="InChIKey", right_on="Metadata_InChIKey", how="inner"
)
jump_moa
# Out:
#                        InChIKey  \
# 0   ZYVXTMKTGDARKR-UHFFFAOYSA-N
#
# 13      histone lysine methyltransferase inhibitor       trt
# 14                                  FGFR inhibitor       trt
# 15                                   JNK inhibitor       trt
# 16               protein tyrosine kinase inhibitor       trt
# 17                                   MEK inhibitor       trt
# 18                     smoothened receptor agonist       trt
# 19                         Aurora kinase inhibitor       trt
# 20   inosine monophosphate dehydrogenase inhibitor       trt
# 21                            MAP kinase inhibitor       trt
# 22                         phospholipase inhibitor       trt
# 23                                   MDM inhibitor       trt
# 24         pyruvate dehydrogenase kinase inhibitor       trt
# 25      histone lysine methyltransferase inhibitor       trt
# 26                                   JNK inhibitor       trt
# 27                              p38 MAPK inhibitor       trt
# 28                         phospholipase inhibitor       trt
# 29                        Bcr-Abl kinase inhibitor       trt
# 30         pyruvate dehydrogenase kinase inhibitor       trt
# 31                                   antihistamine       trt
# 32                            MAP kinase inhibitor       trt
# 33                                     LXR agonist       trt
# 34  protein arginine N-methyltransferase inhibitor       trt
# 35                                   antihistamine       trt
# 36                                   RAF inhibitor       trt
# 37               acetylcholine receptor antagonist       trt
# 38              hypoxia inducible factor inhibitor       trt
# 39      tumor necrosis factor production inhibitor       trt
# 40              glycogen synthase kinase inhibitor       trt
# 41           ubiquitin specific protease inhibitor       trt
#
#                                                smiles Metadata_JCP2022  \
# 0   COc1cc(ccc1Nc1nccc(n1)-c1cn(C)c2cnccc12)N1CCN(...   JCP2022_116560
# 1          CN(C)CCCNC(=O)c1ccc(cc1)-c1cc(O)c2ncccc2c1   JCP2022_072637
# 2   O=C(Nc1nc2cccc(-c3ccc(CN4CCS(=O)(=O)CC4)cc3)n2...   JCP2022_078581
# 3          CC1(N)CCN(CC1)c1cnc(c(N)n1)-c1cccc(Cl)c1Cl   JCP2022_108339
# 4           Cn1cc(cn1)-c1ccc2nnc(Sc3ccc4ncccc4c3)n2n1   JCP2022_005529
# 5                         Cc1c(O)nc2Nc3cccc(Cl)c3Cn12   JCP2022_103938
# 6     CCOC(=O)CCNc1cc(nc(n1)-c1ccccn1)N1CCc2ccccc2CC1   JCP2022_097676
# 7     CC(C)c1ccccc1-c1ncc(C)c(NCc2ccc(cc2)-n2ccnn2)n1   JCP2022_096342
# 8   CCC(=O)Nc1cccc(Oc2nc(Nc3ccc(cc3OC)N3CCN(C)CC3)...   JCP2022_082441
# 9   CN1CCN(Cc2ccc(NC(=O)c3ccc(C)c(c3)C#Cc3cnc4cccn...   JCP2022_068713
# 10          COc1ccccc1S(=O)(=O)Nc1ccc2NC(=O)N(C)Cc2c1   JCP2022_087474
# 11                          [O-][N+]N(CCCl)C(=O)NCCCl   JCP2022_016670
# 12  OC(=O)Cc1cccc(OCCCN(CC(c2ccccc2)c2ccccc2)Cc2cc...   JCP2022_057825
# 13  COc1cc2c(NC3CCN(CC3)C(C)C)nc(nc2cc1OCCCN1CCCC1...   JCP2022_079444
# 14  COc1cc(OC)c(Cl)c(-c2ccc3nc(Nc4c(C)cccc4NC(=O)C...   JCP2022_087308
# 15                   Nc1nnc(Sc2ncc(s2)[N+]([O-])=O)s1   JCP2022_060734
# 16            COc1cc(O)c2C(=O)c3c(O)cc(C)cc3C(=O)c2c1   JCP2022_020389
InChI=1S/C12H7Cl2NO3S2/c1-6(16)10-5-8(15(17)18...

# %%
moa
# Out:
#                        InChIKey                                          moa  \
# 0   ZYVXTMKTGDARKR-UHFFFAOYSA-N                               DYRK inhibitor
# 1   ODADKLYLWWCHNB-LDYBVBFYSA-N                              HMGCR inhibitor
# 2   QDBVSOZTVKXUES-UHFFFAOYSA-N         histone lysine demethylase inhibitor
# 3   CXJCGSPAPOTTSF-VURMDHGXSA-N                                CDC inhibitor
# 4   RFZQYGBLRIKROZ-PCLIKHOPSA-N  phosphoinositide dependent kinase inhibitor
# ..                          ...                                          ...
# 86  FPYJSJDOHRDAMT-KQWNVCNZSA-N  hepatocyte growth factor receptor inhibitor
# 87  DDLZLOKCJHBUHD-UJZLGWIISA-N           glycogen synthase kinase inhibitor
# 88  AQGNHMOJWBZFQQ-UHFFFAOYSA-N           glycogen synthase kinase inhibitor
# 89  LKZLGMAAKNEGCH-UHFFFAOYSA-N        ubiquitin specific protease inhibitor
# 90  IAZDPXIOMUYVGZ-UHFFFAOYSA-N                                          NaN
#
#    pert_type                                             smiles
# 0        trt  COc1cc(ccc1Nc1nccc(n1)-c1cn(C)c2cnccc12)N1CCN(...
# 1        trt  CC(C)=CCC\C(C)=C\CC\C(C)=C\CC[C@]1(C)CCc2cc(O)...
# 2        trt         CN(C)CCCNC(=O)c1ccc(cc1)-c1cc(O)c2ncccc2c1
# 3        trt        CCOC(=O)c1c(\C(=C/N)C#N)c2ccc(Cl)c(Cl)c2n1C
# 4        trt  Cc1cccc(\C=N\Nc2cc(N3CCOCC3)n3nc(cc3n2)-c2ccnc...
# ..       ...                                                ...
# 86       trt  CN(c1cccc(Cl)c1)S(=O)(=O)c1ccc2NC(=O)\C(=C/c3[...
# 87       trt        O\N=C1/C(Nc2ccccc12)=C1/C(=O)Nc2cc(Br)ccc12
# 88       trt  Cc1c[nH]c(n1)-c1cnc(NCCNc2ccc(cn2)C#N)nc1-c1cc...
# 89       trt       CC(=O)c1cc(c(Sc2cccc(Cl)c2Cl)s1)[N+]([O-])=O
# 90   control                                            CS(=O)C
#
# [91 rows x 4 columns]

# %%
moa_wells = moa.dropna(subset=["InChIKey", "moa"]).merge(
    meta, left_on="InChIKey", right_on="Metadata_InChIKey", how="inner"
)

# %%
moa_wells
# Out:
#                          InChIKey                                    moa  \
# 0     ZYVXTMKTGDARKR-UHFFFAOYSA-N                         DYRK inhibitor
# 1     ZYVXTMKTGDARKR-UHFFFAOYSA-N                         DYRK inhibitor
# 2     ZYVXTMKTGDARKR-UHFFFAOYSA-N                         DYRK inhibitor
# 3     ZYVXTMKTGDARKR-UHFFFAOYSA-N                         DYRK inhibitor
# 4     ZYVXTMKTGDARKR-UHFFFAOYSA-N                         DYRK inhibitor
# ...                           ...                                    ...
# 8817  AQGNHMOJWBZFQQ-UHFFFAOYSA-N     glycogen synthase kinase inhibitor
# 8818  LKZLGMAAKNEGCH-UHFFFAOYSA-N  ubiquitin specific protease inhibitor
# 8819  LKZLGMAAKNEGCH-UHFFFAOYSA-N  ubiquitin specific protease inhibitor
# 8820  LKZLGMAAKNEGCH-UHFFFAOYSA-N  ubiquitin specific protease inhibitor
# 8821  LKZLGMAAKNEGCH-UHFFFAOYSA-N  ubiquitin specific protease inhibitor
#
#      pert_type                                             smiles  \
# 0          trt  COc1cc(ccc1Nc1nccc(n1)-c1cn(C)c2cnccc12)N1CCN(...
# 1          trt  COc1cc(ccc1Nc1nccc(n1)-c1cn(C)c2cnccc12)N1CCN(...
# 2          trt  COc1cc(ccc1Nc1nccc(n1)-c1cn(C)c2cnccc12)N1CCN(...
# 3          trt  COc1cc(ccc1Nc1nccc(n1)-c1cn(C)c2cnccc12)N1CCN(...
# 4          trt  COc1cc(ccc1Nc1nccc(n1)-c1cn(C)c2cnccc12)N1CCN(...
# ...        ...                                                ...
# 8817       trt  Cc1c[nH]c(n1)-c1cnc(NCCNc2ccc(cn2)C#N)nc1-c1cc...
# 8818       trt       CC(=O)c1cc(c(Sc2cccc(Cl)c2Cl)s1)[N+]([O-])=O
# 8819       trt       CC(=O)c1cc(c(Sc2cccc(Cl)c2Cl)s1)[N+]([O-])=O
# 8820       trt       CC(=O)c1cc(c(Sc2cccc(Cl)c2Cl)s1)[N+]([O-])=O
# 8821       trt       CC(=O)c1cc(c(Sc2cccc(Cl)c2Cl)s1)[N+]([O-])=O
#
#      Metadata_Source               Metadata_Batch     Metadata_Plate  \
# 0          source_10  2021_08_03_U2OS_48_hr_run12  Dest210726-160150
# 1          source_10  2021_08_09_U2OS_48_hr_run13  Dest210727-153003
# 2          source_10  2021_08_12_U2OS_48_hr_run15  Dest210803-153958
# 3          source_10  2021_08_17_U2OS_48_hr_run16  Dest210809-134534
# 4          source_10  2021_08_20_U2OS_48_hr_run17  Dest210810-173723
# ...              ...                          ...                ...
# 8817        source_8                           J3           A1170543
# 8818        source_2            20210823_Batch_10         1086291979
# 8819        source_3                         CP60           BR5874b3
# 8820        source_3            CP_36_all_Phenix1           BAY5874b
# 8821        source_8                           J3           A1170542
#
#      Metadata_PlateType Metadata_Well Metadata_JCP2022  \
# 0               TARGET2           J09   JCP2022_116560
# 1               TARGET2           J09   JCP2022_116560
# 2               TARGET2           J09   JCP2022_116560
# 3               TARGET2           J09   JCP2022_116560
# 4               TARGET2           J09   JCP2022_116560
# ...                 ...           ...              ...
# 8817           COMPOUND           G17   JCP2022_003104
# 8818           COMPOUND           E18   JCP2022_050096
# 8819           COMPOUND           C20   JCP2022_050096
# 8820           COMPOUND           C20   JCP2022_050096
# 8821           COMPOUND           C20   JCP2022_050096
#
#                 Metadata_InChIKey  \
# 0     ZYVXTMKTGDARKR-UHFFFAOYSA-N
# 1     ZYVXTMKTGDARKR-UHFFFAOYSA-N
# 2     ZYVXTMKTGDARKR-UHFFFAOYSA-N
# 3     ZYVXTMKTGDARKR-UHFFFAOYSA-N
# 4     ZYVXTMKTGDARKR-UHFFFAOYSA-N
# ...                           ...
# 8817  AQGNHMOJWBZFQQ-UHFFFAOYSA-N
# 8818  LKZLGMAAKNEGCH-UHFFFAOYSA-N
# 8819  LKZLGMAAKNEGCH-UHFFFAOYSA-N
# 8820  LKZLGMAAKNEGCH-UHFFFAOYSA-N
# 8821  LKZLGMAAKNEGCH-UHFFFAOYSA-N
#
#                                          Metadata_InChI  \
# 0     InChI=1S/C24H27N7O/c1-29-10-12-31(13-11-29)17-...
# 1     InChI=1S/C24H27N7O/c1-29-10-12-31(13-11-29)17-...
# 2     InChI=1S/C24H27N7O/c1-29-10-12-31(13-11-29)17-...
# 3     InChI=1S/C24H27N7O/c1-29-10-12-31(13-11-29)17-...
# 4     InChI=1S/C24H27N7O/c1-29-10-12-31(13-11-29)17-...
# ...                                                 ...
# 8817  InChI=1S/C22H18Cl2N8/c1-13-10-29-21(31-13)17-1...
# 8818  InChI=1S/C12H7Cl2NO3S2/c1-6(16)10-5-8(15(17)18...
# 8819  InChI=1S/C12H7Cl2NO3S2/c1-6(16)10-5-8(15(17)18...
# 8820  InChI=1S/C12H7Cl2NO3S2/c1-6(16)10-5-8(15(17)18...
# 8821  InChI=1S/C12H7Cl2NO3S2/c1-6(16)10-5-8(15(17)18...
#
#       Metadata_Sites_Per_Well           trt
# 0                           6    target_trt
# 1                           6    target_trt
# 2                           6    target_trt
# 3                           6    target_trt
# 4                           6    target_trt
# ...                       ...           ...
# 8817                        9  compound_trt
# 8818                        6  compound_trt
# 8819                        9  compound_trt
# 8820                        9  compound_trt
# 8821                        9  compound_trt
#
# [8822 rows x 14 columns]

# %%
moa_wells2 = moa_wells.query("Metadata_PlateType != 'COMPOUND'")

# %%
moa_wells2.groupby("moa").Metadata_Well.nunique()
# Out:
# moa
# Aurora kinase inhibitor                        14
# Bcr-Abl kinase inhibitor                       10
# DYRK inhibitor                                  5
# JAK inhibitor                                   5
# JNK inhibitor                                   5
# bromodomain inhibitor                           5
# hepatocyte growth factor receptor inhibitor     5
# phospholipase inhibitor                         5
# ubiquitin specific protease inhibitor           5
# Name: Metadata_Well, dtype: int64

# %%
# .groupby("moa", as_index=False).apply(lambda x: x.sample(min(900, len(x)), replace=False))
# Out:
# Metadata_Well
# J01     244
# O23     217
# B01     140
# F24     140
# N24     140
# J09     117
# I11     104
# C06     104
# J08     104
# D15     104
# L15     104
# D12     104
# N12     104
# F16     103
# F11      13
# K10      13
# I20      13
# F13      13
# I18      13
# N09      13
# C20      13
# H07      13
# B09      13
# R09       9
# B33       9
# V35       9
# V11       9
# AD09      9
# Y44       9
# F35       9
# N33       9
# AD33      9
# K34       9
# Y20       9
# I44       9
# I42       9
# Y18       9
# Y42       9
# H31       9
# X07       9
# X31       9
# J33       9
# Z09       9
# Z33       9
# F37       9
# V13       9
# V37       9
# C44       9
# S20       9
# S44       9
# AA10      9
# AA34      9
# R33       9
# O24       1
# K01       1
# G24       1
# C01       1
# Name: count, dtype: int64

# %%
moa_wells.query("trt != 'compound_pos'").Metadata_PlateType.value_counts()
# Out:
# Metadata_PlateType
# TARGET2     1399
# CRISPR       564
# ORF          217
# COMPOUND     151
# TARGET1       40
# Name: count, dtype: int64

# %%
moa_load_df = load_df.merge(
    moa_wells, on=["Metadata_Source", "Metadata_Batch", "Metadata_Plate", "Metadata_Well"], how="right"
)

# %%
moa_load_df
# Out:
#       Metadata_Source               Metadata_Batch     Metadata_Plate  \
# 0           source_10  2021_08_03_U2OS_48_hr_run12  Dest210726-160150
# 1           source_10  2021_08_03_U2OS_48_hr_run12  Dest210726-160150
# 2           source_10  2021_08_03_U2OS_48_hr_run12  Dest210726-160150
# 3           source_10  2021_08_03_U2OS_48_hr_run12  Dest210726-160150
# 4           source_10  2021_08_03_U2OS_48_hr_run12  Dest210726-160150
# ...               ...                          ...                ...
# 31273        source_8                           J3           A1170542
# 31274        source_8                           J3           A1170542
# 31275        source_8                           J3           A1170542
# 31276        source_8                           J3           A1170542
# 31277        source_8                           J3           A1170542
#
#       Metadata_Well  Metadata_Site  \
# 0               J09              1
# 1               J09              2
# 2               J09              3
# 3               J09              4
# 4               J09              5
# ...             ...            ...
# 31273           C20              4
# 31274           C20              5
# 31275           C20              7
# 31276           C20              8
# 31277           C20              9
#
#                                         FileName_OrigAGP  \
# 0      /projects/cpjump3/jump/images/source_10/2021_0...
# 1      /projects/cpjump3/jump/images/source_10/2021_0...
# 2      /projects/cpjump3/jump/images/source_10/2021_0...
# 3      /projects/cpjump3/jump/images/source_10/2021_0...
# 4      /projects/cpjump3/jump/images/source_10/2021_0...
# ...                                                  ...
# 31273  /projects/cpjump2/jump/images/source_8/J3/A117...
# 31274  /projects/cpjump2/jump/images/source_8/J3/A117...
# 31275  /projects/cpjump2/jump/images/source_8/J3/A117...
# 31276  /projects/cpjump2/jump/images/source_8/J3/A117...
# 31277  /projects/cpjump2/jump/images/source_8/J3/A117...
#
#                                         FileName_OrigDNA  \
# 0      /projects/cpjump3/jump/images/source_10/2021_0...
# 1      /projects/cpjump3/jump/images/source_10/2021_0...
# 2      /projects/cpjump3/jump/images/source_10/2021_0...
# 3      /projects/cpjump3/jump/images/source_10/2021_0...
# 4      /projects/cpjump3/jump/images/source_10/2021_0...
# ...                                                  ...
# 31273  /projects/cpjump2/jump/images/source_8/J3/A117...
# 31274  /projects/cpjump2/jump/images/source_8/J3/A117...
# 31275  /projects/cpjump2/jump/images/source_8/J3/A117...
# 31276  /projects/cpjump2/jump/images/source_8/J3/A117...
# 31277  /projects/cpjump2/jump/images/source_8/J3/A117...
#
#                                          FileName_OrigER  \
# 0      /projects/cpjump3/jump/images/source_10/2021_0...
# 1      /projects/cpjump3/jump/images/source_10/2021_0...
# 2      /projects/cpjump3/jump/images/source_10/2021_0...
# 3      /projects/cpjump3/jump/images/source_10/2021_0...
# 4      /projects/cpjump3/jump/images/source_10/2021_0...
# ...                                                  ...
# 31273  /projects/cpjump2/jump/images/source_8/J3/A117...
# 31274  /projects/cpjump2/jump/images/source_8/J3/A117...
# 31275  /projects/cpjump2/jump/images/source_8/J3/A117...
# 31276  /projects/cpjump2/jump/images/source_8/J3/A117...
# 31277  /projects/cpjump2/jump/images/source_8/J3/A117...
#
#                                        FileName_OrigMito  \
# 0      /projects/cpjump3/jump/images/source_10/2021_0...
# 1      /projects/cpjump3/jump/images/source_10/2021_0...
# 2      /projects/cpjump3/jump/images/source_10/2021_0...
# 3      /projects/cpjump3/jump/images/source_10/2021_0...
# 4      /projects/cpjump3/jump/images/source_10/2021_0...
# ...                                                  ...
# 31273  /projects/cpjump2/jump/images/source_8/J3/A117...
# 31274  /projects/cpjump2/jump/images/source_8/J3/A117...
# 31275  /projects/cpjump2/jump/images/source_8/J3/A117...
# 31276  /projects/cpjump2/jump/images/source_8/J3/A117...
# 31277  /projects/cpjump2/jump/images/source_8/J3/A117...
#
#                                         FileName_OrigRNA  \
# 0      /projects/cpjump3/jump/images/source_10/2021_0...
# 1      /projects/cpjump3/jump/images/source_10/2021_0...
# 2      /projects/cpjump3/jump/images/source_10/2021_0...
# 3      /projects/cpjump3/jump/images/source_10/2021_0...
# 4      /projects/cpjump3/jump/images/source_10/2021_0...
# ...                                                  ...
# 31273  /projects/cpjump2/jump/images/source_8/J3/A117...
# 31274  /projects/cpjump2/jump/images/source_8/J3/A117...
# 31275  /projects/cpjump2/jump/images/source_8/J3/A117...
# 31276  /projects/cpjump2/jump/images/source_8/J3/A117...
# 31277  /projects/cpjump2/jump/images/source_8/J3/A117...
#
#                           InChIKey                                    moa  \
# 0      ZYVXTMKTGDARKR-UHFFFAOYSA-N                         DYRK inhibitor
# 1      ZYVXTMKTGDARKR-UHFFFAOYSA-N                         DYRK inhibitor
# 2      ZYVXTMKTGDARKR-UHFFFAOYSA-N                         DYRK inhibitor
# 3      ZYVXTMKTGDARKR-UHFFFAOYSA-N                         DYRK inhibitor
# 4      ZYVXTMKTGDARKR-UHFFFAOYSA-N                         DYRK inhibitor
# ...                            ...                                    ...
# 31273  LKZLGMAAKNEGCH-UHFFFAOYSA-N  ubiquitin specific protease inhibitor
# 31274  LKZLGMAAKNEGCH-UHFFFAOYSA-N  ubiquitin specific protease inhibitor
# 31275  LKZLGMAAKNEGCH-UHFFFAOYSA-N  ubiquitin specific protease inhibitor
# 31276  LKZLGMAAKNEGCH-UHFFFAOYSA-N  ubiquitin specific protease inhibitor
# 31277  LKZLGMAAKNEGCH-UHFFFAOYSA-N  ubiquitin specific protease inhibitor
#
#       pert_type                                             smiles  \
# 0           trt  COc1cc(ccc1Nc1nccc(n1)-c1cn(C)c2cnccc12)N1CCN(...
# 1           trt  COc1cc(ccc1Nc1nccc(n1)-c1cn(C)c2cnccc12)N1CCN(...
# 2           trt  COc1cc(ccc1Nc1nccc(n1)-c1cn(C)c2cnccc12)N1CCN(...
# 3           trt  COc1cc(ccc1Nc1nccc(n1)-c1cn(C)c2cnccc12)N1CCN(...
# 4           trt  COc1cc(ccc1Nc1nccc(n1)-c1cn(C)c2cnccc12)N1CCN(...
# ...         ...                                                ...
# 31273       trt       CC(=O)c1cc(c(Sc2cccc(Cl)c2Cl)s1)[N+]([O-])=O
# 31274       trt       CC(=O)c1cc(c(Sc2cccc(Cl)c2Cl)s1)[N+]([O-])=O
# 31275       trt       CC(=O)c1cc(c(Sc2cccc(Cl)c2Cl)s1)[N+]([O-])=O
# 31276       trt       CC(=O)c1cc(c(Sc2cccc(Cl)c2Cl)s1)[N+]([O-])=O
# 31277       trt       CC(=O)c1cc(c(Sc2cccc(Cl)c2Cl)s1)[N+]([O-])=O
#
#       Metadata_PlateType Metadata_JCP2022            Metadata_InChIKey  \
# 0                TARGET2   JCP2022_116560  ZYVXTMKTGDARKR-UHFFFAOYSA-N
# 1                TARGET2   JCP2022_116560  ZYVXTMKTGDARKR-UHFFFAOYSA-N
# 2                TARGET2   JCP2022_116560  ZYVXTMKTGDARKR-UHFFFAOYSA-N
# 3                TARGET2   JCP2022_116560  ZYVXTMKTGDARKR-UHFFFAOYSA-N
# 4                TARGET2   JCP2022_116560  ZYVXTMKTGDARKR-UHFFFAOYSA-N
# ...                  ...              ...                          ...
# 31273           COMPOUND   JCP2022_050096  LKZLGMAAKNEGCH-UHFFFAOYSA-N
# 31274           COMPOUND   JCP2022_050096  LKZLGMAAKNEGCH-UHFFFAOYSA-N
# 31275           COMPOUND   JCP2022_050096  LKZLGMAAKNEGCH-UHFFFAOYSA-N
# 31276           COMPOUND   JCP2022_050096  LKZLGMAAKNEGCH-UHFFFAOYSA-N
# 31277           COMPOUND   JCP2022_050096  LKZLGMAAKNEGCH-UHFFFAOYSA-N
#
#                                           Metadata_InChI  \
# 0      InChI=1S/C24H27N7O/c1-29-10-12-31(13-11-29)17-...
# 1      InChI=1S/C24H27N7O/c1-29-10-12-31(13-11-29)17-...
# 2      InChI=1S/C24H27N7O/c1-29-10-12-31(13-11-29)17-...
# 3      InChI=1S/C24H27N7O/c1-29-10-12-31(13-11-29)17-...
# 4      InChI=1S/C24H27N7O/c1-29-10-12-31(13-11-29)17-...
# ...                                                  ...
# 31273  InChI=1S/C12H7Cl2NO3S2/c1-6(16)10-5-8(15(17)18...
# 31274  InChI=1S/C12H7Cl2NO3S2/c1-6(16)10-5-8(15(17)18...
# 31275  InChI=1S/C12H7Cl2NO3S2/c1-6(16)10-5-8(15(17)18...
# 31276  InChI=1S/C12H7Cl2NO3S2/c1-6(16)10-5-8(15(17)18...
# 31277  InChI=1S/C12H7Cl2NO3S2/c1-6(16)10-5-8(15(17)18...
#
#        Metadata_Sites_Per_Well           trt
# 0                            6    target_trt
# 1                            6    target_trt
# 2                            6    target_trt
# 3                            6    target_trt
# 4                            6    target_trt
# ...                        ...           ...
# 31273                        9  compound_trt
# 31274                        9  compound_trt
# 31275                        9  compound_trt
# 31276                        9  compound_trt
# 31277                        9  compound_trt
#
# [31278 rows x 20 columns]

# %%
sampled_targets = moa_load_df.groupby("moa", as_index=False).apply(lambda x: x.sample(min(900, len(x)), replace=False))

# %%
moa_load_df.moa.value_counts()
# Out:
# moa
# Aurora kinase inhibitor                           23268
# Bcr-Abl kinase inhibitor                           1608
# ubiquitin specific protease inhibitor               846
# JAK inhibitor                                       816
# bromodomain inhibitor                               816
# DYRK inhibitor                                      816
# hepatocyte growth factor receptor inhibitor         816
# JNK inhibitor                                       810
# phospholipase inhibitor                             808
# glycogen synthase kinase inhibitor                   78
# antihistamine                                        78
# pyruvate dehydrogenase kinase inhibitor              64
# histone lysine methyltransferase inhibitor           48
# histone lysine demethylase inhibitor                 48
# LXR agonist                                          48
# acetylcholine receptor antagonist                    46
# smoothened receptor agonist                          36
# MAP kinase inhibitor                                 30
# tumor necrosis factor production inhibitor           30
# FGFR inhibitor                                       24
# MDM inhibitor                                        24
# p38 MAPK inhibitor                                   24
# protein arginine N-methyltransferase inhibitor       24
# RAF inhibitor                                        24
# hypoxia inducible factor inhibitor                   24
# AMPK inhibitor                                       24
# Name: count, dtype: int64

# %% [markdown]
# ## Dataset

# %%
class JumpMOADataset(Dataset):
    def __init__(
        self,
        moa_load_df: pd.DataFrame,
        transform: Optional[Callable] = None,
        compound_transform: Optional[Callable] = None,
        return_image: bool = True,
        return_compound: bool = False,
        target_col: str = "moa",
        smiles_col: str = "smiles",
        use_cache: bool = True,
        channels: Optional[List[str]] = None,
        data_root_dir: Optional[str] = None,
    ):
        """Initializes the dataset.

        Args:
            moa_load_df (pd.DataFrame):
                The load dataframe with the metadata.
            transform (Optional[Callable], optional):
                The transform to apply to the images.
            compound_transform (Optional[Callable], optional):
                The compound transform to apply to the compounds.
                Defaults to None.
            use_cache (bool, optional):
                Whether to use a cache for the compounds.
                Defaults to True.
            smiles_col (str, optional):
                The name of the column with the smiles.
                Defaults to "smiles".
            channels (Optional[List[str]], optional):
                The channels to use.
                Defaults to None.
            return_image (bool, optional):
                Whether to return the image.
                Defaults to True.
            return_compound (bool, optional):
                Whether to return the compound.
                Defaults to False.
        """
        super().__init__()

        self.moa_load_df = moa_load_df
        self.target_col = target_col
        self.smiles_col = smiles_col
        self.channels = channels or ["DNA", "AGP", "ER", "Mito", "RNA"]
        self.return_image = return_image
        self.return_compound = return_compound

        if data_root_dir:
            for channel in self.channels:
                self.moa_load_df.loc[:, f"FileName_Orig{channel}"] = self.moa_load_df[
                    f"FileName_Orig{channel}"
                ].str.replace("/projects/", data_root_dir)

        self.targets = self.moa_load_df[self.target_col].unique()
        self.targets.sort()
        self.target_to_num = {target: i for i, target in enumerate(self.targets)}

        self.transform = transform
        self.compound_transform = compound_transform

        self.n_compounds = moa_load_df[smiles_col].nunique()
        self.n_images = len(self.moa_load_df)

        self.use_cache = use_cache
        self.compound_cache = {}

    def __len__(self):
        return self.n_images

    def __repr__(self) -> str:
        return f"{self.__class__.__name__}(n_compounds={self.n_compounds}, n_images={self.n_images})"

    def get_transformed_compound(self, compound):
        if self.use_cache and compound in self.compound_cache:
            return self.compound_cache[compound]
        else:
            transformed_compound = self.compound_transform(compound)
            if self.use_cache:
                self.compound_cache[compound] = transformed_compound
            return transformed_compound

    def get_default_collate_fn(self):
        """Return the default collate function that should be used for this dataset."""
        if self.return_compound and self.return_image:
            return image_graph_label_collate_function
        elif not self.return_compound:
            return None
        elif not self.return_image:
            return label_graph_collate_function

    def __getitem__(self, idx: int):
        """Returns the data at the given index.

        Args:
            idx (int):
                The index of the data to return.

        Returns:
            Tuple[str, torch.Tensor]:
                The smile and the classes.
        """
        row = self.moa_load_df.iloc[idx]
        output = {"label": self.target_to_num[row[self.target_col]]}

        if self.return_image:
            img_paths = [row[f"FileName_Orig{channel}"] for channel in self.channels]

            img_array = load_image_paths_to_array(img_paths)  # A numpy array: (5, 768, 768)
            img_array = torch.from_numpy(img_array)

            if self.transform:
                img_array = self.transform(img_array)

            output["image"] = img_array

        if self.return_compound:
            smile = self.moa_load_df[self.smiles_col].iloc[idx]

            if self.compound_transform:
                transformed_compound = self.get_transformed_compound(smile)
            else:
                transformed_compound = smile

            output["compound"] = transformed_compound

        return output

# %% [markdown]
# ### Tests

# %%
for channel in ["DNA", "AGP", "ER", "Mito", "RNA"]:
    moa_load_df[f"FileName_Orig{channel}"] = moa_load_df[f"FileName_Orig{channel}"].str.replace("/projects/", "../")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 for channel in ['DNA', 'AGP', 'ER', 'Mito', 'RNA']:
# ----> 2     moa_load_df[f"FileName_Orig{channel}"] = moa_load_df[f"FileName_Orig{channel}"].str.replace("/projects/", "../")
#
# NameError: name 'moa_load_df' is not defined

# %%
moa_load_df
# Out:
#       Metadata_Source               Metadata_Batch     Metadata_Plate  \
# 0           source_10  2021_08_03_U2OS_48_hr_run12  Dest210726-160150
# 1           source_10  2021_08_03_U2OS_48_hr_run12  Dest210726-160150
# 2           source_10  2021_08_03_U2OS_48_hr_run12  Dest210726-160150
# 3           source_10  2021_08_03_U2OS_48_hr_run12  Dest210726-160150
# 4           source_10  2021_08_03_U2OS_48_hr_run12  Dest210726-160150
# ...               ...                          ...                ...
# 31273        source_8                           J3           A1170542
# 31274        source_8                           J3           A1170542
# 31275        source_8                           J3           A1170542
# 31276        source_8                           J3           A1170542
# 31277        source_8                           J3           A1170542
#
#       Metadata_Well  Metadata_Site  \
# 0               J09              1
# 1               J09              2
# 2               J09              3
# 3               J09              4
# 4               J09              5
# ...             ...            ...
# 31273           C20              4
# 31274           C20              5
# 31275           C20              7
# 31276           C20              8
# 31277           C20              9
#
#                                         FileName_OrigAGP  \
# 0      ../cpjump3/jump/images/source_10/2021_08_03_U2...
# 1      ../cpjump3/jump/images/source_10/2021_08_03_U2...
# 2      ../cpjump3/jump/images/source_10/2021_08_03_U2...
# 3      ../cpjump3/jump/images/source_10/2021_08_03_U2...
# 4      ../cpjump3/jump/images/source_10/2021_08_03_U2...
# ...                                                  ...
# 31273  ../cpjump2/jump/images/source_8/J3/A1170542/so...
# 31274  ../cpjump2/jump/images/source_8/J3/A1170542/so...
# 31275  ../cpjump2/jump/images/source_8/J3/A1170542/so...
# 31276  ../cpjump2/jump/images/source_8/J3/A1170542/so...
# 31277  ../cpjump2/jump/images/source_8/J3/A1170542/so...
#
#                                         FileName_OrigDNA  \
# 0      ../cpjump3/jump/images/source_10/2021_08_03_U2...
# 1      ../cpjump3/jump/images/source_10/2021_08_03_U2...
# 2      ../cpjump3/jump/images/source_10/2021_08_03_U2...
# 3      ../cpjump3/jump/images/source_10/2021_08_03_U2...
# 4      ../cpjump3/jump/images/source_10/2021_08_03_U2...
# ...                                                  ...
# 31273  ../cpjump2/jump/images/source_8/J3/A1170542/so...
# 31274  ../cpjump2/jump/images/source_8/J3/A1170542/so...
# 31275  ../cpjump2/jump/images/source_8/J3/A1170542/so...
# 31276  ../cpjump2/jump/images/source_8/J3/A1170542/so...
# 31277  ../cpjump2/jump/images/source_8/J3/A1170542/so...
#
#                                          FileName_OrigER  \
# 0      ../cpjump3/jump/images/source_10/2021_08_03_U2...
# 1      ../cpjump3/jump/images/source_10/2021_08_03_U2...
# 2      ../cpjump3/jump/images/source_10/2021_08_03_U2...
# 3      ../cpjump3/jump/images/source_10/2021_08_03_U2...
# 4      ../cpjump3/jump/images/source_10/2021_08_03_U2...
# ...                                                  ...
# 31273  ../cpjump2/jump/images/source_8/J3/A1170542/so...
# 31274  ../cpjump2/jump/images/source_8/J3/A1170542/so...
# 31275  ../cpjump2/jump/images/source_8/J3/A1170542/so...
# 31276  ../cpjump2/jump/images/source_8/J3/A1170542/so...
# 31277  ../cpjump2/jump/images/source_8/J3/A1170542/so...
#
#                                        FileName_OrigMito  \
# 0      ../cpjump3/jump/images/source_10/2021_08_03_U2...
# 1      ../cpjump3/jump/images/source_10/2021_08_03_U2...
# 2      ../cpjump3/jump/images/source_10/2021_08_03_U2...
# 3      ../cpjump3/jump/images/source_10/2021_08_03_U2...
# 4      ../cpjump3/jump/images/source_10/2021_08_03_U2...
# ...                                                  ...
# 31273  ../cpjump2/jump/images/source_8/J3/A1170542/so...
# 31274  ../cpjump2/jump/images/source_8/J3/A1170542/so...
# 31275  ../cpjump2/jump/images/source_8/J3/A1170542/so...
# 31276  ../cpjump2/jump/images/source_8/J3/A1170542/so...
# 31277  ../cpjump2/jump/images/source_8/J3/A1170542/so...
#
#                                         FileName_OrigRNA  \
# 0      ../cpjump3/jump/images/source_10/2021_08_03_U2...
# 1      ../cpjump3/jump/images/source_10/2021_08_03_U2...
# 2      ../cpjump3/jump/images/source_10/2021_08_03_U2...
# 3      ../cpjump3/jump/images/source_10/2021_08_03_U2...
# 4      ../cpjump3/jump/images/source_10/2021_08_03_U2...
# ...                                                  ...
# 31273  ../cpjump2/jump/images/source_8/J3/A1170542/so...
# 31274  ../cpjump2/jump/images/source_8/J3/A1170542/so...
# 31275  ../cpjump2/jump/images/source_8/J3/A1170542/so...
# 31276  ../cpjump2/jump/images/source_8/J3/A1170542/so...
# 31277  ../cpjump2/jump/images/source_8/J3/A1170542/so...
#
#                           InChIKey                                    moa  \
# 0      ZYVXTMKTGDARKR-UHFFFAOYSA-N                         DYRK inhibitor
# 1      ZYVXTMKTGDARKR-UHFFFAOYSA-N                         DYRK inhibitor
# 2      ZYVXTMKTGDARKR-UHFFFAOYSA-N                         DYRK inhibitor
# 3      ZYVXTMKTGDARKR-UHFFFAOYSA-N                         DYRK inhibitor
# 4      ZYVXTMKTGDARKR-UHFFFAOYSA-N                         DYRK inhibitor
# ...                            ...                                    ...
# 31273  LKZLGMAAKNEGCH-UHFFFAOYSA-N  ubiquitin specific protease inhibitor
# 31274  LKZLGMAAKNEGCH-UHFFFAOYSA-N  ubiquitin specific protease inhibitor
# 31275  LKZLGMAAKNEGCH-UHFFFAOYSA-N  ubiquitin specific protease inhibitor
# 31276  LKZLGMAAKNEGCH-UHFFFAOYSA-N  ubiquitin specific protease inhibitor
# 31277  LKZLGMAAKNEGCH-UHFFFAOYSA-N  ubiquitin specific protease inhibitor
#
#       pert_type                                             smiles  \
# 0           trt  COc1cc(ccc1Nc1nccc(n1)-c1cn(C)c2cnccc12)N1CCN(...
# 1           trt  COc1cc(ccc1Nc1nccc(n1)-c1cn(C)c2cnccc12)N1CCN(...
# 2           trt  COc1cc(ccc1Nc1nccc(n1)-c1cn(C)c2cnccc12)N1CCN(...
# 3           trt  COc1cc(ccc1Nc1nccc(n1)-c1cn(C)c2cnccc12)N1CCN(...
# 4           trt  COc1cc(ccc1Nc1nccc(n1)-c1cn(C)c2cnccc12)N1CCN(...
# ...         ...                                                ...
# 31273       trt       CC(=O)c1cc(c(Sc2cccc(Cl)c2Cl)s1)[N+]([O-])=O
# 31274       trt       CC(=O)c1cc(c(Sc2cccc(Cl)c2Cl)s1)[N+]([O-])=O
# 31275       trt       CC(=O)c1cc(c(Sc2cccc(Cl)c2Cl)s1)[N+]([O-])=O
# 31276       trt       CC(=O)c1cc(c(Sc2cccc(Cl)c2Cl)s1)[N+]([O-])=O
# 31277       trt       CC(=O)c1cc(c(Sc2cccc(Cl)c2Cl)s1)[N+]([O-])=O
#
#       Metadata_PlateType Metadata_JCP2022            Metadata_InChIKey  \
# 0                TARGET2   JCP2022_116560  ZYVXTMKTGDARKR-UHFFFAOYSA-N
# 1                TARGET2   JCP2022_116560  ZYVXTMKTGDARKR-UHFFFAOYSA-N
# 2                TARGET2   JCP2022_116560  ZYVXTMKTGDARKR-UHFFFAOYSA-N
# 3                TARGET2   JCP2022_116560  ZYVXTMKTGDARKR-UHFFFAOYSA-N
# 4                TARGET2   JCP2022_116560  ZYVXTMKTGDARKR-UHFFFAOYSA-N
# ...                  ...              ...                          ...
# 31273           COMPOUND   JCP2022_050096  LKZLGMAAKNEGCH-UHFFFAOYSA-N
# 31274           COMPOUND   JCP2022_050096  LKZLGMAAKNEGCH-UHFFFAOYSA-N
# 31275           COMPOUND   JCP2022_050096  LKZLGMAAKNEGCH-UHFFFAOYSA-N
# 31276           COMPOUND   JCP2022_050096  LKZLGMAAKNEGCH-UHFFFAOYSA-N
# 31277           COMPOUND   JCP2022_050096  LKZLGMAAKNEGCH-UHFFFAOYSA-N
#
#                                           Metadata_InChI  \
# 0      InChI=1S/C24H27N7O/c1-29-10-12-31(13-11-29)17-...
# 1      InChI=1S/C24H27N7O/c1-29-10-12-31(13-11-29)17-...
# 2      InChI=1S/C24H27N7O/c1-29-10-12-31(13-11-29)17-...
# 3      InChI=1S/C24H27N7O/c1-29-10-12-31(13-11-29)17-...
# 4      InChI=1S/C24H27N7O/c1-29-10-12-31(13-11-29)17-...
# ...                                                  ...
# 31273  InChI=1S/C12H7Cl2NO3S2/c1-6(16)10-5-8(15(17)18...
# 31274  InChI=1S/C12H7Cl2NO3S2/c1-6(16)10-5-8(15(17)18...
# 31275  InChI=1S/C12H7Cl2NO3S2/c1-6(16)10-5-8(15(17)18...
# 31276  InChI=1S/C12H7Cl2NO3S2/c1-6(16)10-5-8(15(17)18...
# 31277  InChI=1S/C12H7Cl2NO3S2/c1-6(16)10-5-8(15(17)18...
#
#        Metadata_Sites_Per_Well           trt
# 0                            6    target_trt
# 1                            6    target_trt
# 2                            6    target_trt
# 3                            6    target_trt
# 4                            6    target_trt
# ...                        ...           ...
# 31273                        9  compound_trt
# 31274                        9  compound_trt
# 31275                        9  compound_trt
# 31276                        9  compound_trt
# 31277                        9  compound_trt
#
# [31278 rows x 20 columns]

# %%
dataset = JumpMOADataset(
    moa_load_df=moa_load_df,
    transform=DefaultJUMPTransform(size=256),
    compound_transform=DGLPretrainedFromSmiles(),
    return_image=True,
    return_compound=True,
)

# %%
dataset[0]
# Out:
# {'label': 3,
#  'image': tensor([[[-0.2042, -0.2285, -0.2285,  ..., -0.2285, -0.2285, -0.2042],
#           [-0.2285, -0.2528, -0.2528,  ..., -0.1556, -0.1799, -0.1556],
#           [-0.2285, -0.1312, -0.1312,  ..., -0.1799, -0.2528, -0.2285],
#           ...,
#           [-0.1556, -0.2285, -0.2528,  ..., -0.2042, -0.2528, -0.2042],
#           [-0.2042, -0.2285, -0.2042,  ..., -0.2042, -0.1069, -0.2528],
#           [-0.2285, -0.2042, -0.2042,  ..., -0.2528, -0.1556, -0.2285]],
#
#          [[-0.3619, -0.3619, -0.3619,  ...,  1.1231,  0.8756,  0.7519],
#           [-0.3371, -0.3619, -0.3619,  ...,  0.4054,  0.6529,  0.5786],
#           [-0.3371, -0.3619, -0.3619,  ..., -0.0154,  0.5539,  0.6776],
#           ...,
#           [-0.3866, -0.3866, -0.3866,  ...,  0.9004,  1.0241,  0.9004],
#           [-0.3619, -0.3866, -0.3619,  ...,  0.8756,  1.1974,  1.4449],
#           [-0.3619, -0.3619, -0.3866,  ...,  0.8509,  1.1974,  1.4944]],
#
#          [[-0.3536, -0.3316, -0.3756,  ..., -0.0456,  0.3503,  1.0102],
#           [-0.3756, -0.3756, -0.3316,  ..., -0.1776,  0.1523,  0.6143],
#           [-0.3536, -0.3316, -0.3096,  ..., -0.3096, -0.1336,  0.1523],
#           ...,
#           [-0.3536, -0.3536, -0.3756,  ..., -0.0016,  0.0204,  0.0864],
#           [-0.3316, -0.3536, -0.3536,  ...,  0.1963,  0.2843,  0.2843],
#           [-0.3316, -0.3756, -0.3536,  ...,  0.2843,  0.3723,  0.3503]],
#
#          [[ 0.0706, -0.1450,  0.0398,  ...,  0.0398,  0.4711,  0.4711],
#           [-0.0218, -0.0834, -0.0218,  ...,  0.0090,  0.1938,  0.3479],
#           [-0.0526, -0.0526, -0.1142,  ..., -0.1758, -0.0834,  0.2246],
#           ...,
#           [-0.6686, -0.6378, -0.5146,  ..., -0.4838, -0.4838, -0.4222],
#           [-0.4530, -0.6070, -0.4838,  ..., -0.3298, -0.2990, -0.1758],
#           [-0.4838, -0.4222, -0.3914,  ..., -0.2682, -0.2374,  0.0090]],
#
#          [[-0.3319, -0.3554, -0.3319,  ...,  0.0446,  0.4211,  0.8211],
#           [-0.3319, -0.3319, -0.3554,  ..., -0.1436,  0.2799,  0.4917],
#           [-0.3554, -0.3319, -0.3319,  ..., -0.2377, -0.0730,  0.2329],
#           ...,
#           [-0.3789, -0.3789, -0.3554,  ...,  0.1387,  0.1152,  0.0917],
#           [-0.3554, -0.3554, -0.3319,  ...,  0.2799,  0.3035,  0.4211],
#           [-0.3554, -0.3554, -0.3554,  ...,  0.4682,  0.6094,  0.6094]]]),
#  'compound': Graph(num_nodes=32, num_edges=104,
#        ndata_schemes={'atomic_number': Scheme(shape=(), dtype=torch.int64), 'chirality_type': Scheme(shape=(), dtype=torch.int64)}
#        edata_schemes={'bond_type': Scheme(shape=(), dtype=torch.int64), 'bond_direction_type': Scheme(shape=(), dtype=torch.int64)})}

# %%
dl = DataLoader(dataset=dataset, batch_size=32, shuffle=True, collate_fn=dataset.get_default_collate_fn())

# %%
b = next(iter(dl))

# %%
b
# Out:
# {'label': tensor([ 1.,  1., 20.,  1., 20., 15.,  1.,  1.,  1.,  1.,  1.,  3.,  1.,  2.,
#           1.,  1.,  1.,  1.,  3.,  1.,  1.,  6.,  1.,  1.,  1.,  1.,  1.,  5.,
#           1.,  1.,  1.,  1.]),
#  'image': tensor([[[[-3.0593e-01, -3.0593e-01, -3.0593e-01,  ...,  5.4897e+00,
#              5.7895e+00,  4.1407e+00],
#            [-2.5597e-01, -3.3091e-01, -3.0593e-01,  ...,  5.2898e+00,
#              4.4904e+00,  5.1400e+00],
#            [-3.8087e-01, -3.5589e-01, -4.0585e-01,  ...,  4.5154e+00,
#              3.8659e+00,  4.0158e+00],
#            ...,
#            [-3.0593e-01, -3.5589e-01, -3.3091e-01,  ..., -3.5589e-01,
#             -3.3091e-01, -4.3083e-01],
#            [-3.8087e-01, -3.0593e-01, -3.3091e-01,  ..., -3.3091e-01,
#             -3.8087e-01, -3.3091e-01],
#            [-3.8087e-01, -3.8087e-01, -4.0585e-01,  ..., -4.3083e-01,
#             -3.8087e-01, -3.8087e-01]],
#
#           [[-6.6179e-01, -3.8758e-01, -5.0510e-01,  ...,  2.0411e+00,
#              3.0400e+00,  2.7854e+00],
#            [-5.4427e-01, -7.2055e-01, -4.6593e-01,  ...,  1.9628e+00,
#              2.3545e+00,  2.1586e+00],
#            [-3.4841e-01, -6.2262e-01,  4.3317e-02,  ...,  2.0607e+00,
#              2.2957e+00,  2.2370e+00],
#            ...,
#            [-1.5255e-01, -7.4202e-02, -1.5255e-01,  ..., -7.2055e-01,
#             -7.4014e-01, -7.4014e-01],
#            [-2.1131e-01, -1.9172e-01, -4.6593e-01,  ..., -6.0303e-01,
#             -5.2469e-01, -7.7931e-01],
#            [-7.4202e-02, -1.5255e-01, -2.7007e-01,  ..., -7.0097e-01,
#             -6.4221e-01, -7.2055e-01]],
#
#           [[-3.5484e-01, -4.4512e-01, -4.2255e-01,  ...,  1.8345e+00,
#              2.1279e+00,  2.0827e+00],
#            [-2.4199e-01, -3.3227e-01, -3.7741e-01,  ...,  1.9473e+00,
#              2.0376e+00,  1.7893e+00],
#            [-2.8713e-01, -3.3227e-01, -3.0970e-01,  ...,  1.9699e+00,
#              1.8345e+00,  1.7667e+00],
#            ...,
#            [-6.0311e-01, -6.0311e-01, -6.7082e-01,  ..., -6.0311e-01,
#             -5.8054e-01, -6.0311e-01],
#            [-6.2568e-01, -6.4825e-01, -6.0311e-01,  ..., -6.2568e-01,
#             -6.2568e-01, -6.4825e-01],
#            [-5.5797e-01, -5.8054e-01, -5.8054e-01,  ..., -6.2568e-01,
#             -6.0311e-01, -6.7082e-01]],
#
#           [[-3.4929e-01, -5.2676e-01, -4.1584e-01,  ...,  9.8175e-01,
#              8.0428e-01,  1.0927e+00],
#            [-3.9366e-01, -3.4929e-01, -4.3803e-01,  ...,  1.0039e+00,
#             -1.0088e+00, -9.9168e-01],
#            [-1.6862e-01, -1.1718e-01, -1.5148e-01,  ..., -1.0260e+00,
#             -1.0088e+00, -9.9168e-01],
#            [-1.1718e-01, -1.4301e-02, -3.1448e-02,  ..., -1.0088e+00,
#             -1.0088e+00, -1.0260e+00]]]]),
#  'compound': Graph(num_nodes=1120, num_edges=3654,
#        ndata_schemes={'atomic_number': Scheme(shape=(), dtype=torch.int64), 'chirality_type': Scheme(shape=(), dtype=torch.int64)}
#        edata_schemes={'bond_type': Scheme(shape=(), dtype=torch.int64), 'bond_direction_type': Scheme(shape=(), dtype=torch.int64)})}

# %%
b["image"].shape
# Out:
# torch.Size([32, 5, 256, 256])

# %% [markdown]
# ## DataModule

# %%
dataloader_config = DictConfig(
    {
        "train": {
            "batch_size": 16,
            "num_workers": 4,
            "shuffle": True,
        },
        "val": {
            "batch_size": 16,
            "num_workers": 4,
            "shuffle": False,
        },
        "test": {
            "batch_size": 16,
            "num_workers": 4,
            "shuffle": False,
        },
    }
)

# %%
dm = JumpMOADataModule(
    moa_load_df_path="../cpjump1/jump/models/eval/test/moa_1000.csv",
    split_path="../cpjump1/jump/models/eval/test/",
    dataloader_config=dataloader_config,
    force_split=False,
    transform=DefaultJUMPTransform(size=256),
    compound_transform=DGLPretrainedFromSmiles(),
    return_image=True,
    return_compound=True,
    collate_fn=None,
    metadata_dir="../cpjump1/jump/metadata",
    load_data_dir="../cpjump1/jump/load_data",
    splitter=StratifiedSplitter(
        train=0.75,
        val=0.15,
        test=0.1,
    ),
    max_obs_per_class=1000,
)

# %%
logging.basicConfig(level=logging.INFO)

# %%
dm.prepare_data()

# %%
dm.setup("train", data_root_dir="../")

# %%
torch.save(b, "../cpjump1/jump/models/eval/test/example.pt")

# %%
image_encoder = CNNEncoder("resnet18", target_num=128)
# Out:
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/resnet18.a1_in1k)
# INFO:timm.models._hub:[timm/resnet18.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# INFO:src.modules.images.timm_pretrained:Using model resnet/resnest with projection head

# %%
molecule_encoder = GINPretrainedWithLinearHead("gin_supervised_infomax", out_dim=128)
# Out:
# INFO:src.modules.molecules.dgllife_gin:Using pretrained model: gin_supervised_infomax
# Downloading gin_supervised_infomax_pre_trained.pth from https://data.dgl.ai/dgllife/pre_trained/gin_supervised_infomax.pth...
# Pretrained model loaded

# %%
model = JumpMOAImageModule(
    image_encoder=image_encoder,
    optimizer=torch.optim.Adam,
    scheduler=None,
    criterion=None,
    cross_modal_module=None,
    example_input=b,
)

# %%
model
# Out:
# JumpMOAImageModule(
#   (image_encoder): CNNEncoder(
#     (backbone): ResNet(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (drop_block): Identity()
#           (act1): ReLU(inplace=True)
#           (aa): Identity()
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): ReLU(inplace=True)
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (drop_block): Identity()
#           (act1): ReLU(inplace=True)
#           (aa): Identity()
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (drop_block): Identity()
#           (act1): ReLU(inplace=True)
#           (aa): Identity()
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (drop_block): Identity()
#           (act1): ReLU(inplace=True)
#           (aa): Identity()
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (drop_block): Identity()
#           (act1): ReLU(inplace=True)
#           (aa): Identity()
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (drop_block): Identity()
#           (act1): ReLU(inplace=True)
#           (aa): Identity()
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (drop_block): Identity()
#           (act1): ReLU(inplace=True)
#           (aa): Identity()
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (drop_block): Identity()
#           (act1): ReLU(inplace=True)
#           (aa): Identity()
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act2): ReLU(inplace=True)
#         )
#       )
#       (global_pool): SelectAdaptivePool2d (pool_type=avg, flatten=Flatten(start_dim=1, end_dim=-1))
#       (fc): Identity()
#     )
#     (entry): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (projection_head): Linear(in_features=512, out_features=128, bias=True)
#     (dropouts): ModuleList(
#       (0-4): 5 x Dropout(p=0.5, inplace=False)
#     )
#   )
#   (head): Linear(in_features=128, out_features=26, bias=True)
#   (criterion): CrossEntropyLoss()
#   (train_loss): MeanMetric()
#   (val_loss): MeanMetric()
#   (test_loss): MeanMetric()
#   (train_other_metrics): MetricCollection(
#     (MulticlassAUROC_top_1): MulticlassAUROC()
#     (MulticlassAccuracy_top_1): MulticlassAccuracy()
#     (MulticlassAccuracy_top_10): MulticlassAccuracy()
#     (MulticlassAccuracy_top_3): MulticlassAccuracy()
#     (MulticlassAccuracy_top_5): MulticlassAccuracy()
#     (MulticlassF1Score_top_1): MulticlassF1Score()
#     (MulticlassF1Score_top_5): MulticlassF1Score(),
#     prefix=jump_moa/image/train/
#   )
#   (val_other_metrics): MetricCollection(
#     (MulticlassAUROC_top_1): MulticlassAUROC()
#     (MulticlassAccuracy_top_1): MulticlassAccuracy()
#     (MulticlassAccuracy_top_10): MulticlassAccuracy()
#     (MulticlassAccuracy_top_3): MulticlassAccuracy()
#     (MulticlassAccuracy_top_5): MulticlassAccuracy()
#     (MulticlassF1Score_top_1): MulticlassF1Score()
#     (MulticlassF1Score_top_5): MulticlassF1Score(),
#     prefix=jump_moa/image/val/
#   )
#   (test_other_metrics): MetricCollection(
#     (MulticlassAUROC_top_1): MulticlassAUROC()
#     (MulticlassAccuracy_top_1): MulticlassAccuracy()
#     (MulticlassAccuracy_top_10): MulticlassAccuracy()
#     (MulticlassAccuracy_top_3): MulticlassAccuracy()
#     (MulticlassAccuracy_top_5): MulticlassAccuracy()
#     (MulticlassF1Score_top_1): MulticlassF1Score()
#     (MulticlassF1Score_top_5): MulticlassF1Score(),
#     prefix=jump_moa/image/test/
#   )
#   (train_plot_metrics): MetricCollection(
#     (MulticlassConfusionMatrix): MulticlassConfusionMatrix()
#     (MulticlassConfusionMatrix_normalized): MulticlassConfusionMatrix(),
#     prefix=jump_moa/image/train/
#   )
#   (val_plot_metrics): MetricCollection(
#     (MulticlassConfusionMatrix): MulticlassConfusionMatrix()
#     (MulticlassConfusionMatrix_normalized): MulticlassConfusionMatrix(),
#     prefix=jump_moa/image/val/
#   )
#   (test_plot_metrics): MetricCollection(
#     (MulticlassConfusionMatrix): MulticlassConfusionMatrix()
#     (MulticlassConfusionMatrix_normalized): MulticlassConfusionMatrix(),
#     prefix=jump_moa/image/test/
#   )
# )

# %%
logger = WandbLogger(project="jump_moa", log_model=True, group="debug")
trainer = Trainer(max_epochs=5, logger=logger)
# Out:
# /home/gwatk/miniconda3/envs/jump_models/lib/python3.10/site-packages/lightning/pytorch/loggers/wandb.py:396: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs

# %%
model(**b)
# Out:
# tensor([[-0.0015, -0.0026, -0.0322, -0.0981, -0.0607,  0.0043,  0.0200, -0.0356,
#          -0.0269, -0.0480, -0.0120,  0.0151,  0.0308,  0.0494, -0.0364, -0.0587,
#           0.0831,  0.0616, -0.0041, -0.0368, -0.0117,  0.0286,  0.0584, -0.0170,
#           0.0418,  0.0571],
#         [ 0.0431,  0.0387, -0.0616, -0.0470, -0.0454,  0.0400, -0.0117, -0.0495,
#          -0.0074, -0.0596, -0.0026, -0.0100,  0.0266,  0.0082, -0.0329, -0.0936,
#           0.0742,  0.0481, -0.0047, -0.0305,  0.0184,  0.0241,  0.0328, -0.0024,
#           0.0200,  0.0087],
#         [ 0.0217,  0.0231, -0.0398, -0.0545, -0.0935,  0.0154,  0.0294, -0.0766,
#          -0.0098, -0.0666, -0.0524,  0.0256,  0.0063,  0.0221, -0.0084, -0.0642,
#           0.0077,  0.0614, -0.0200, -0.0372, -0.0124,  0.0236,  0.0473,  0.0358,
#           0.0296,  0.0135],
#         [ 0.0176,  0.0184, -0.0262, -0.0352, -0.0913,  0.0009,  0.0535, -0.0424,
#          -0.0165, -0.0665, -0.0252, -0.0154, -0.0270,  0.0104,  0.0493, -0.0633,
#           0.0073,  0.0348, -0.0349, -0.0622, -0.0292,  0.0375,  0.0558,  0.0376,
#           0.0214,  0.0151]], grad_fn=<AddmmBackward0>)

# %%
b["label"]
# Out:
# tensor([ 0, 14, 13, 15])

# %%
criterion = nn.CrossEntropyLoss()

# %%
x = model(**b)
y = b["label"]

# %%
criterion(x, y)
# Out:
# tensor(3.2844, grad_fn=<NllLossBackward0>)

# %%
trainer.fit(model, dm)
# Out:
# You are using a CUDA device ('NVIDIA GeForce RTX 3070 Laptop GPU') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#    | Name                | Type                        | Params | In sizes         | Out sizes
# ----------------------------------------------------------------------------------------------------
# 0  | image_encoder       | CNNEncoder                  | 11.2 M | [4, 5, 256, 256] | [4, 128]
# 1  | head                | Sequential                  | 72.5 K | [4, 256]         | [4, 26]
# 2  | criterion           | CrossEntropyLoss            | 0      | ?                | ?
# 3  | train_loss          | MeanMetric                  | 0      | ?                | ?
# 4  | val_loss            | MeanMetric                  | 0      | ?                | ?
# 5  | test_loss           | MeanMetric                  | 0      | ?                | ?
# 6  | train_other_metrics | MetricCollection            | 0      | ?                | ?
# 7  | val_other_metrics   | MetricCollection            | 0      | ?                | ?
# 8  | test_other_metrics  | MetricCollection            | 0      | ?                | ?
# 9  | train_plot_metrics  | MetricCollection            | 0      | ?                | ?
# 10 | val_plot_metrics    | MetricCollection            | 0      | ?                | ?
# 11 | test_plot_metrics   | MetricCollection            | 0      | ?                | ?
# 12 | molecule_encoder    | GINPretrainedWithLinearHead | 1.9 M  | ?                | [4, 128]
# ----------------------------------------------------------------------------------------------------
# 13.2 M    Trainable params
# 0         Non-trainable params
# 13.2 M    Total params
# 52.869    Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# /home/gwatk/miniconda3/envs/jump_models/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:42: UserWarning: No positive samples in targets, true positive value should be meaningless. Returning zero tensor in true positive score
#   warnings.warn(*args, **kwargs)  # noqa: B028
# /home/gwatk/miniconda3/envs/jump_models/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:76: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 16. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# Training: 0it [00:00, ?it/s]
# /home/gwatk/miniconda3/envs/jump_models/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:76: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 13. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# Validation: 0it [00:00, ?it/s]
# /home/gwatk/miniconda3/envs/jump_models/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:76: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 14. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# Validation: 0it [00:00, ?it/s]
# /home/gwatk/miniconda3/envs/jump_models/lib/python3.10/site-packages/lightning/pytorch/trainer/call.py:52: UserWarning: Detected KeyboardInterrupt, attempting graceful shutdown...
#   rank_zero_warn("Detected KeyboardInterrupt, attempting graceful shutdown...")

# %%
b
# Out:
# {'label': tensor([ 0, 14, 13, 15]),
#  'image': tensor([[[[-1.1375, -0.3726,  0.1374,  ..., -1.1375, -0.6275,  0.3923],
#            [ 0.9023,  0.6473,  1.4122,  ...,  0.9023, -0.1176,  0.3923],
#            [-0.3726, -1.6474,  0.6473,  ...,  0.3923,  2.4321, -0.1176],
#            ...,
#            [ 0.3923,  0.6473, -1.1375,  ...,  0.6473, -0.1176,  1.6672],
#            [-0.6275, -0.3726, -0.6275,  ...,  0.6473,  1.6672, -0.1176],
#            [-0.1176, -0.6275, -1.1375,  ..., -1.6474, -0.6275,  0.6473]],
#
#           [[-0.3807, -0.5040, -0.1957,  ..., -0.1957, -0.0723, -0.1340],
#            [-0.5040, -0.4424, -0.2573,  ..., -0.0723, -0.0723, -0.1340],
#            [-0.2573, -0.4424, -0.3807,  ..., -0.1957, -0.1340, -0.1340],
#            ...,
#            [-0.1340, -0.1340, -0.0723,  ..., -0.1340,  0.1127, -0.0106],
#            [-0.0106, -0.1957, -0.3190,  ..., -0.3190, -0.0723,  0.1127],
#            [-0.1340, -0.0106, -0.1340,  ..., -0.1340, -0.0723, -0.0723]],
#
#           [[-0.1535, -0.2926, -0.2926,  ..., -0.1535,  0.1248, -0.1535],
#            [-0.2926, -0.1535, -0.1535,  ..., -0.0143, -0.4317, -0.1535],
#            [-0.1535, -0.4317, -0.1535,  ...,  0.1248, -0.0143, -0.0143],
#            ...,
#            [-0.0143,  0.1248, -0.0143,  ..., -0.0143, -0.1535,  0.1248],
#            [-0.1535, -0.1535, -0.1535,  ..., -0.0143,  0.2639, -0.0143],
#            [-0.2926,  0.1248, -0.2926,  ..., -0.0143, -0.0143, -0.1535]],
#
#           [[-1.3441, -1.6484, -1.4455,  ...,  0.9890,  0.3804,  1.0904],
#            [-1.0398, -1.5470, -1.0398,  ...,  0.1775,  0.5832, -0.3297],
#            [-0.4311, -0.9383, -1.3441,  ...,  0.0760,  0.3804,  0.4818],
#            ...,
#            [-1.4455, -1.3441, -1.2426,  ..., -0.1268,  0.7861,  0.3804],
#            [-1.6484, -1.9527, -1.9527,  ..., -0.5326,  0.7861,  0.5832],
#            [-2.0541, -1.2426, -1.6484,  ...,  0.5832,  0.4818,  0.3804]],
#
#           [[-0.1993, -0.0734, -0.5770,  ..., -0.1993, -0.3252, -0.1993],
#            [-0.5770, -0.5770, -0.0734,  ...,  0.0525,  0.6820, -0.1993],
#            [ 0.0525, -0.1993, -0.0734,  ..., -0.4511,  0.4302, -0.3252],
#            ...,
#            [ 0.0525, -0.1993, -0.0734,  ..., -0.3252,  0.0525, -0.1993],
#            [-0.1993, -0.1993,  0.1784,  ...,  0.1784,  0.1784,  0.4302],
#            [-0.1993, -0.1993, -0.0734,  ..., -0.0734, -0.1993, -0.4511]]],
#
#
#          [[[-0.3019, -0.3019, -0.3019,  ..., -0.3019, -0.2803, -0.3019],
#            [-0.2803, -0.3019, -0.3019,  ..., -0.3019, -0.2803, -0.3019],
#            [-0.3235, -0.2803, -0.3019,  ..., -0.3019, -0.3019, -0.3235],
#            ...,
#            [-0.3019, -0.2803, -0.2803,  ..., -0.3019, -0.2803, -0.2803],
#            [-0.2803, -0.2803, -0.2803,  ..., -0.3019, -0.3019, -0.2803],
#            [-0.2803, -0.2587, -0.2803,  ..., -0.3019, -0.2803, -0.3019]],
#
#           [[ 0.5464,  0.5819,  0.5819,  ..., -0.6269, -0.6447, -0.6269],
#            [ 0.6353,  0.5108,  0.4041,  ..., -0.6092, -0.6269, -0.6269],
#            [ 1.2041,  0.8664,  0.9019,  ..., -0.6269, -0.6092, -0.6269],
#            ...,
#            [ 0.7775,  0.6708,  0.8308,  ..., -0.6092, -0.6269, -0.5914],
#            [ 1.3641,  1.8441,  1.9330,  ..., -0.5914, -0.6092, -0.6092],
#            [ 0.4575,  0.9552,  1.5597,  ..., -0.6092, -0.6269, -0.6092]],
#
#           [[-0.1586, -0.1769, -0.2135,  ..., -0.5247, -0.5247, -0.5247],
#            [-0.1769, -0.3233, -0.3599,  ..., -0.5247, -0.5247, -0.5247],
#            [-0.2501, -0.3416, -0.3416,  ..., -0.5247, -0.5247, -0.5430],
#            ...,
#            [ 1.0313,  0.9947,  0.8483,  ..., -0.5247, -0.5064, -0.5247],
#            [ 1.0862,  0.9764,  0.7750,  ..., -0.5247, -0.5247, -0.5064],
#            [ 0.9764,  0.9947,  0.7567,  ..., -0.5247, -0.5430, -0.5064]],
#
#           [[-0.3066, -0.3827, -0.4587,  ..., -0.4207, -0.3827, -0.4587],
#            [-0.3827, -0.4397, -0.4587,  ..., -0.4587, -0.5157, -0.5347],
#            [-0.4017, -0.4017, -0.4967,  ..., -0.5157, -0.4777, -0.5157],
#            ...,
#            [ 1.1570,  1.3471,  1.8603,  ..., -0.5157, -0.4017, -0.4777],
#            [ 1.4992,  0.9859,  0.9099,  ..., -0.4397, -0.4777, -0.4017],
#            [ 0.9859,  0.7198,  0.7578,  ..., -0.3446, -0.3827, -0.4207]],
#
#           [[-0.0107,  0.0438,  0.0438,  ..., -0.5737, -0.6100, -0.5919],
#            [-0.0470, -0.1015, -0.1742,  ..., -0.5737, -0.5919, -0.5919],
#            [ 0.2435,  0.0256,  0.0074,  ..., -0.6100, -0.5919, -0.5919],
#            ...,
#            [ 0.9337,  0.9881,  1.1334,  ..., -0.5556, -0.5374, -0.5556],
#            [ 1.1334,  1.1697,  1.2969,  ..., -0.5556, -0.5556, -0.5737],
#            [ 0.8065,  1.0063,  1.0789,  ..., -0.5374, -0.5919, -0.5556]]],
#
#
#          [[[-0.3978, -0.3808, -0.3978,  ..., -0.3978, -0.3978, -0.3978],
#            [-0.3978, -0.3978, -0.3808,  ..., -0.3978, -0.3978, -0.3808],
#            [-0.3978, -0.3978, -0.3808,  ..., -0.3978, -0.3978, -0.3978],
#            ...,
#            [-0.3808, -0.3978, -0.3808,  ..., -0.3808, -0.3808, -0.3808],
#            [-0.3808, -0.3808, -0.3808,  ..., -0.3808, -0.3978, -0.3808],
#            [-0.3808, -0.3637, -0.3808,  ..., -0.3978, -0.3978, -0.3808]],
#
#           [[-0.8157, -0.7816, -0.7816,  ..., -0.8157, -0.8157, -0.8328],
#            [-0.8157, -0.8157, -0.8157,  ..., -0.8328, -0.8328, -0.8328],
#            [-0.8157, -0.7987, -0.7987,  ..., -0.7987, -0.8157, -0.8328],
#            ...,
#            [ 0.0383, -0.2008, -0.2521,  ..., -0.7816, -0.7645, -0.8328],
#            [-0.0471, -0.2521, -0.2179,  ..., -0.8157, -0.7816, -0.7645],
#            [ 0.1750, -0.0300, -0.0129,  ..., -0.7987, -0.7987, -0.7987]],
#
#           [[-0.7200, -0.7200, -0.7200,  ..., -0.7200, -0.7200, -0.7200],
#            [-0.7200, -0.7040, -0.7200,  ..., -0.7200, -0.7200, -0.7200],
#            [-0.7200, -0.7200, -0.7200,  ..., -0.7200, -0.7200, -0.7200],
#            ...,
#            [-0.5278, -0.6078, -0.6559,  ..., -0.7200, -0.7200, -0.7200],
#            [-0.5758, -0.6399, -0.6559,  ..., -0.7200, -0.7200, -0.7200],
#            [-0.5278, -0.6559, -0.6559,  ..., -0.7200, -0.7200, -0.7040]],
#
#           [[-0.7221, -0.7405, -0.7405,  ..., -0.6854, -0.7037, -0.7221],
#            [-0.7221, -0.7221, -0.7405,  ..., -0.6854, -0.6854, -0.7405],
#            [-0.7037, -0.7221, -0.7037,  ..., -0.7221, -0.7037, -0.7405],
#            ...,
#            [-0.3730, -0.4833, -0.5935,  ..., -0.6302, -0.6486, -0.6486],
#            [-0.3730, -0.5384, -0.5935,  ..., -0.5751, -0.5751, -0.6119],
#            [-0.3914, -0.5016, -0.6119,  ..., -0.6854, -0.6302, -0.6302]],
#
#           [[-0.7316, -0.7155, -0.7638,  ..., -0.6833, -0.7477, -0.7477],
#            [-0.7316, -0.7638, -0.7477,  ..., -0.7316, -0.7477, -0.6994],
#            [-0.7316, -0.7638, -0.7477,  ..., -0.7477, -0.7316, -0.7316],
#            ...,
#            [-0.4260, -0.5547, -0.6190,  ..., -0.6994, -0.7155, -0.7155],
#            [-0.4421, -0.5708, -0.6673,  ..., -0.7155, -0.6673, -0.6833],
#            [-0.4421, -0.5386, -0.6351,  ..., -0.6673, -0.7316, -0.7316]]],
#
#
#          [[[-0.4147, -0.4147, -0.4147,  ..., -0.3973, -0.3973, -0.3973],
#            [-0.3973, -0.4147, -0.4147,  ..., -0.4147, -0.3973, -0.3973],
#            [-0.3973, -0.4147, -0.4147,  ..., -0.3973, -0.3973, -0.3973],
#            ...,
#            [-0.4321, -0.4321, -0.4321,  ..., -0.4147, -0.4147, -0.4147],
#            [-0.4321, -0.4321, -0.4321,  ..., -0.3973, -0.4147, -0.4147],
#            [-0.4495, -0.4321, -0.4321,  ..., -0.4147, -0.4147, -0.4147]],
#
#           [[-0.7654, -0.7794, -0.7794,  ...,  0.3717,  0.4699,  0.5682],
#            [-0.7654, -0.7794, -0.7934,  ...,  0.2734,  0.3576,  0.4138],
#            [-0.7654, -0.7654, -0.7794,  ...,  0.2313,  0.3296,  0.3857],
#            ...,
#            [-0.7654, -0.7654, -0.7513,  ..., -0.7794, -0.7794, -0.7794],
#            [-0.7794, -0.7794, -0.7794,  ..., -0.7794, -0.7794, -0.7654],
#            [-0.7654, -0.7654, -0.7794,  ..., -0.7934, -0.7794, -0.7794]],
#
#           [[-0.6956, -0.6956, -0.6956,  ..., -0.4293, -0.4013, -0.3732],
#            [-0.7096, -0.6956, -0.6956,  ..., -0.4854, -0.4713, -0.4293],
#            [-0.6956, -0.6816, -0.6816,  ..., -0.4994, -0.4713, -0.4293],
#            ...,
#            [-0.6956, -0.7096, -0.7096,  ..., -0.6816, -0.6816, -0.6956],
#            [-0.7096, -0.7096, -0.7096,  ..., -0.6816, -0.6816, -0.6816],
#            [-0.7096, -0.7096, -0.7096,  ..., -0.6816, -0.6816, -0.6956]],
#
#           [[-0.5160, -0.5536, -0.5348,  ..., -0.4597, -0.4034, -0.3471],
#            [-0.5348, -0.5536, -0.5348,  ..., -0.4597, -0.4785, -0.4409],
#            [-0.5348, -0.5723, -0.5348,  ..., -0.4785, -0.4409, -0.3846],
#            ...,
#            [-0.6474, -0.6474, -0.6474,  ..., -0.6662, -0.6662, -0.7037],
#            [-0.6286, -0.6474, -0.6662,  ..., -0.6662, -0.6850, -0.6850],
#            [-0.6662, -0.6474, -0.6474,  ..., -0.6850, -0.7037, -0.7037]],
#
#           [[-0.7085, -0.7224, -0.7085,  ..., -0.4039, -0.3623, -0.3208],
#            [-0.7085, -0.7224, -0.7224,  ..., -0.4870, -0.4593, -0.4454],
#            [-0.7085, -0.7224, -0.7224,  ..., -0.5008, -0.4870, -0.4731],
#            ...,
#            [-0.7362, -0.7362, -0.7362,  ..., -0.7085, -0.7085, -0.7085],
#            [-0.7224, -0.7224, -0.7224,  ..., -0.7085, -0.7085, -0.7085],
#            [-0.7224, -0.7224, -0.7224,  ..., -0.7085, -0.7085, -0.7085]]]]),
#  'compound': Graph(num_nodes=117, num_edges=375,
#        ndata_schemes={'atomic_number': Scheme(shape=(), dtype=torch.int64), 'chirality_type': Scheme(shape=(), dtype=torch.int64)}
#        edata_schemes={'bond_type': Scheme(shape=(), dtype=torch.int64), 'bond_direction_type': Scheme(shape=(), dtype=torch.int64)})}

# %%
dl = dm.train_dataloader(batch_size=4)

# %%
b = next(iter(dl))

# %%
dm.train_dataset.moa_load_df.moa.nunique()
# Out:
# 26

# %%
b["label"]
# Out:
# tensor([ 0, 14, 13, 15])

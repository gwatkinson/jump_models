# %% [markdown]
# # Check for negative controls in all the plates

# %%
import os
import os.path as osp

import pandas as pd
import seaborn as sns
import yaml

# %%
metadata_path = "../cpjump1/jump/metadata"
load_data_path = "../cpjump1/jump/load_data"

# %%
os.listdir(metadata_path)
# Out:
# ['compound.csv.gz',
#  'crispr.csv.gz',
#  'microscope_config.csv',
#  'microscope_filter.csv',
#  'orf.csv.gz',
#  'plate.csv.gz',
#  'README.md',
#  'well.csv.gz',
#  'compound.csv',
#  'crispr.csv',
#  'orf.csv',
#  'plate.csv',
#  'well.csv',
#  'complete_metadata.csv',
#  'resolution.csv',
#  'JUMP-Target-1_compound_metadata.tsv',
#  'JUMP-Target-1_compound_platemap.tsv',
#  'JUMP-Target-1_crispr_metadata.tsv',
#  'JUMP-Target-1_crispr_platemap.tsv',
#  'JUMP-Target-1_orf_metadata.tsv',
#  'JUMP-Target-1_orf_platemap.tsv',
#  'JUMP-Target-2_compound_metadata.tsv',
#  'JUMP-Target-2_compound_platemap.tsv',
#  'JUMP-MOA_compound_metadata.tsv']

# %%
os.listdir("../cpjump1/jump/load_data")
# Out:
# ['load_data_with_metadata', 'load_data_with_samples', 'final']

# %%
with open(
    "/mnt/2547d4d7-6732-4154-b0e1-17b0c1e0c565/Document-2/Projet2/Stage/workspace/jump_download/conf/filters/filters_default.yaml",
) as f:
    filters = yaml.load(f, Loader=yaml.FullLoader)

# %%
filters
# Out:
# {'plate_types_to_keep': ['COMPOUND', 'ORF', 'CRISPR', 'TARGET1', 'TARGET2'],
#  'sources_to_exclude': ['source_7'],
#  'compound_number_of_poscon_to_keep_per_well': 4,
#  'compound_number_of_negcon_to_keep_per_well': 3,
#  'compound_number_of_trt_to_keep_per_well': 6,
#  'orf_number_of_poscon_to_keep_per_well': 4,
#  'orf_number_of_negcon_to_keep_per_well': 3,
#  'orf_number_of_trt_to_keep_per_well': 6,
#  'crispr_number_of_poscon_to_keep_per_well': 4,
#  'crispr_number_of_negcon_to_keep_per_well': 3,
#  'crispr_number_of_trt_to_keep_per_well': 6,
#  'target_number_of_poscon_to_keep_per_well': 4,
#  'target_number_of_negcon_to_keep_per_well': 3,
#  'target_number_of_trt_to_keep_per_well': 6,
#  'compound_negative_controls': ['JCP2022_033924'],
#  'compound_positive_controls': ['JCP2022_037716',
#   'JCP2022_064022',
#   'JCP2022_025848',
#   'JCP2022_050797',
#   'JCP2022_046054',
#   'JCP2022_012818',
#   'JCP2022_085227',
#   'JCP2022_035095',
#   'JCP2022_033954'],
#  'compound_pert_to_drop': [],
#  'orf_negative_controls': ['JCP2022_915129',
#   'JCP2022_915128',
#   'JCP2022_915131',
#   'JCP2022_915130'],
#  'orf_positive_controls': ['JCP2022_915132',
#   'JCP2022_037716',
#   'JCP2022_035095',
#   'JCP2022_050797',
#   'JCP2022_012818'],
#  'orf_pert_to_drop': ['JCP2022_999999', 'JCP2022_900001'],
#  'crispr_negative_controls': ['JCP2022_033924',
#   'JCP2022_800001',
#   'JCP2022_800002'],
#  'crispr_positive_controls': ['JCP2022_805264',
#   'JCP2022_085227',
#   'JCP2022_037716',
#   'JCP2022_064022',
#   'JCP2022_025848',
#   'JCP2022_050797',
#   'JCP2022_046054',
#   'JCP2022_012818',
#   'JCP2022_035095',
#   'JCP2022_033954'],
#  'crispr_pert_to_drop': [],
#  'target_negative_controls': ['JCP2022_033924'],
#  'target_positive_controls': [],
#  'target_pert_to_drop': []}

# %%
plates = pd.read_csv(osp.join(metadata_path, "plate.csv"))

# %%
wells = pd.read_csv(osp.join(metadata_path, "well.csv"))

# %%
paw = pd.merge(plates, wells, on=["Metadata_Source", "Metadata_Plate"], how="left")

# %%
paw.groupby(["Metadata_Source", "Metadata_PlateType"]).agg(
    Num_plate=("Metadata_Plate", "nunique"),
)
# Out:
#                                     Num_plate
# Metadata_Source Metadata_PlateType
# source_1        COMPOUND                   51
#                 COMPOUND_EMPTY              4
# source_10       COMPOUND                  208
#                 DMSO                        8
#                 TARGET2                     6
# source_11       COMPOUND                  173
#                 TARGET2                     7
# source_13       CRISPR                    148
#                 TARGET2                     6
# source_2        COMPOUND                  219
#                 TARGET2                    10
# source_3        COMPOUND                  237
#                 COMPOUND_EMPTY              3
#                 DMSO                       38
#                 TARGET2                    25
# source_4        ORF                       251
#                 TARGET1                     4
#                 TARGET2                    22
# source_5        COMPOUND                  197
#                 DMSO                       31
#                 POSCON8                     8
#                 TARGET2                    24
# source_6        COMPOUND                  225
#                 TARGET2                    21
# source_7        COMPOUND                  121
#                 TARGET2                     7
# source_8        COMPOUND                  199
#                 COMPOUND_EMPTY             13
#                 TARGET2                     4
# source_9        COMPOUND                   99
#                 TARGET2                     9

# %%
paw.Metadata_PlateType.value_counts()
# Out:
# Metadata_PlateType
# COMPOUND          832295
# ORF                96377
# TARGET2            64485
# CRISPR             56832
# DMSO               29566
# COMPOUND_EMPTY     11914
# POSCON8             3072
# TARGET1             1533
# Name: count, dtype: int64

# %%
meta = pd.read_csv(osp.join(metadata_path, "complete_metadata.csv"))
# Out:
# /tmp/ipykernel_8748/2571030615.py:1: DtypeWarning: Columns (2,8,9,10,11,12,13,14,15,18,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   meta = pd.read_csv(osp.join(metadata_path, "complete_metadata.csv"))

# %%
filters["orf_positive_controls"]
# Out:
# ['JCP2022_915132',
#  'JCP2022_037716',
#  'JCP2022_035095',
#  'JCP2022_050797',
#  'JCP2022_012818']

# %%
meta["Metadata_JCP2022"].isin(filters["orf_positive_controls"]).sum()
# Out:
# 38856

# %%
(meta["Metadata_JCP2022"].isin(filters["orf_positive_controls"]) & meta["Metadata_PlateType"] == "ORF").sum()
# Out:
# 0

# %%
well_types = meta.assign(
    compound_negative_controls=lambda df: df["Metadata_JCP2022"].isin(filters["compound_negative_controls"])
    & ~df["Metadata_PlateType"].isin(["ORF", "CRISPR", "TARGET1", "TARGET2"]),
    compound_positive_controls=lambda df: df["Metadata_JCP2022"].isin(filters["compound_positive_controls"])
    & ~df["Metadata_PlateType"].isin(["ORF", "CRISPR", "TARGET1", "TARGET2"]),
    compound_to_drop=lambda df: df["Metadata_JCP2022"].isin(filters["compound_pert_to_drop"])
    & ~df["Metadata_PlateType"].isin(["ORF", "CRISPR", "TARGET1", "TARGET2"]),
    orf_negative_controls=lambda df: df["Metadata_JCP2022"].isin(filters["orf_negative_controls"])
    & df["Metadata_PlateType"]
    == "ORF",
    orf_positive_controls=lambda df: df["Metadata_JCP2022"].isin(filters["orf_positive_controls"])
    & df["Metadata_PlateType"]
    == "ORF",
    orf_to_drop=lambda df: df["Metadata_JCP2022"].isin(filters["orf_pert_to_drop"]) & df["Metadata_PlateType"] == "ORF",
    crispr_positive_controls=lambda df: df["Metadata_JCP2022"].isin(filters["crispr_positive_controls"])
    & df["Metadata_PlateType"]
    == "CRISPR",
    crispr_negative_controls=lambda df: df["Metadata_JCP2022"].isin(filters["crispr_negative_controls"])
    & df["Metadata_PlateType"]
    == "CRISPR",
    crispr_to_drop=lambda df: df["Metadata_JCP2022"].isin(filters["crispr_pert_to_drop"]) & df["Metadata_PlateType"]
    == "CRISPR",
    target_negative_controls=lambda df: df["Metadata_JCP2022"].isin(filters["target_negative_controls"])
    & df["Metadata_PlateType"].isin(["TARGET1", "TARGET2"]),
    target_positive_controls=lambda df: df["Metadata_JCP2022"].isin(filters["target_positive_controls"])
    & df["Metadata_PlateType"].isin(["TARGET1", "TARGET2"]),
    target_to_drop=lambda df: df["Metadata_JCP2022"].isin(filters["target_pert_to_drop"])
    & df["Metadata_PlateType"].isin(["TARGET1", "TARGET2"]),
)

# %%
def col_to_str(x):
    if x["compound_negative_controls"]:
        return "compound_neg"
    elif x["compound_positive_controls"]:
        return "compound_pos"
    elif x["compound_to_drop"]:
        return "compound_drop"
    elif x["orf_negative_controls"]:
        return "orf_neg"
    elif x["orf_positive_controls"]:
        return "orf_pos"
    elif x["orf_to_drop"]:
        return "orf_drop"
    elif x["crispr_negative_controls"]:
        return "crispr_neg"
    elif x["crispr_positive_controls"]:
        return "crispr_pos"
    elif x["crispr_to_drop"]:
        return "crispr_drop"
    elif x["target_negative_controls"]:
        return "target_neg"
    elif x["target_positive_controls"]:
        return "target_pos"
    elif x["target_to_drop"]:
        return "target_drop"
    else:
        if x["Metadata_PlateType"] == "COMPOUND":
            return "compound_trt"
        elif x["Metadata_PlateType"] == "CRISPR":
            return "crispr_trt"
        elif x["Metadata_PlateType"] == "ORF":
            return "orf_trt"
        elif x["Metadata_PlateType"] in ["TARGET1", "TARGET2"]:
            return "target_trt"
        else:
            return "other"

# %%
well_types.orf_negative_controls.sum()
# Out:
# 0

# %%
trt = well_types.apply(col_to_str, axis=1)

# %%
well_types["trt"] = trt

# %%
trt.value_counts()
# Out:
# compound_trt    679106
# compound_neg    126739
# orf_trt          96377
# compound_pos     68442
# crispr_trt       56832
# target_trt       54949
# target_neg       11069
# other             2560
# Name: count, dtype: int64

# %%
q = well_types.groupby(["Metadata_Source", "Metadata_PlateType", "Metadata_Plate"]).compound_negative_controls.sum()
q
# Out:
# Metadata_Source  Metadata_PlateType
# source_1         COMPOUND               9217
#                  COMPOUND_EMPTY         5518
# source_10        COMPOUND               6560
#                  DMSO                   3071
#                  TARGET2                   0
# source_11        COMPOUND               7587
#                  TARGET2                   0
# source_13        CRISPR                    0
#                  TARGET2                   0
# source_2         COMPOUND              10877
#                  TARGET2                   0
# source_3         COMPOUND               7574
#                  COMPOUND_EMPTY           96
#                  DMSO                  14591
#                  TARGET2                   0
# source_4         ORF                       0
#                  TARGET1                   0
#                  TARGET2                   0
# source_5         COMPOUND               6304
#                  DMSO                  11904
#                  POSCON8                   0
#                  TARGET2                   0
# source_6         COMPOUND              12832
#                  TARGET2                   0
# source_7         COMPOUND               7184
#                  TARGET2                   0
# source_8         COMPOUND               7776
#                  COMPOUND_EMPTY         2976
#                  TARGET2                   0
# source_9         COMPOUND              12672
#                  TARGET2                   0
# Name: compound_negative_controls, dtype: int64

# %%
df = pd.read_parquet(osp.join(load_data_path, "final"))

# %%
filtered_meta = df[["Metadata_Source", "Metadata_Batch", "Metadata_Plate", "Metadata_Well"]].drop_duplicates()

# %%
well_types.columns
# Out:
# Index(['Metadata_Source', 'Metadata_Batch', 'Metadata_Plate',
#        'Metadata_PlateType', 'Metadata_Well', 'Metadata_JCP2022',
#        'Metadata_InChIKey', 'Metadata_InChI', 'Metadata_broad_sample',
#        'Metadata_Name', 'Metadata_Vector', 'Metadata_Transcript',
#        'Metadata_Symbol_x', 'Metadata_NCBI_Gene_ID_x', 'Metadata_Taxon_ID',
#        'Metadata_Gene_Description', 'Metadata_Prot_Match',
#        'Metadata_Insert_Length', 'Metadata_pert_type',
#        'Metadata_NCBI_Gene_ID_y', 'Metadata_Symbol_y',
#        'Metadata_Microscope_Name', 'Metadata_Widefield_vs_Confocal',
#        'Metadata_Excitation_Type', 'Metadata_Objective_NA',
#        'Metadata_N_Brightfield_Planes_Min',
#        'Metadata_N_Brightfield_Planes_Max',
#        'Metadata_Distance_Between_Z_Microns', 'Metadata_Sites_Per_Well',
#        'Metadata_Filter_Configuration', 'compound_negative_controls',
#        'compound_positive_controls', 'compound_to_drop',
#        'orf_negative_controls', 'orf_positive_controls', 'orf_to_drop',
#        'crispr_positive_controls', 'crispr_negative_controls',
#        'crispr_to_drop', 'target_negative_controls',
#        'target_positive_controls', 'target_to_drop', 'trt'],
#       dtype='object')

# %%
cols_to_keep = [
    "Metadata_Source",
    "Metadata_Batch",
    "Metadata_Plate",
    "Metadata_PlateType",
    "Metadata_Well",
    "Metadata_JCP2022",
    "Metadata_InChIKey",
    "Metadata_InChI",
    "Metadata_Sites_Per_Well",
    "trt",
]

# %%
filtered_meta = well_types.merge(filtered_meta)[cols_to_keep]

# %%
filtered_meta.trt.value_counts()
# Out:
# trt
# compound_trt    545924
# orf_trt          86935
# compound_neg     65105
# crispr_trt       56832
# compound_pos     51123
# target_trt       45992
# target_neg        9251
# Name: count, dtype: int64

# %%
filtered_meta
# Out:
#        Metadata_Source   Metadata_Batch Metadata_Plate Metadata_PlateType  \
# 0             source_1  Batch1_20221004       UL001641           COMPOUND
# 1             source_1  Batch1_20221004       UL001641           COMPOUND
# 2             source_1  Batch1_20221004       UL001641           COMPOUND
# 3             source_1  Batch1_20221004       UL001641           COMPOUND
# 4             source_1  Batch1_20221004       UL001641           COMPOUND
# ...                ...              ...            ...                ...
# 861157        source_9   20211103-Run16     GR00004421           COMPOUND
# 861158        source_9   20211103-Run16     GR00004421           COMPOUND
# 861159        source_9   20211103-Run16     GR00004421           COMPOUND
# 861160        source_9   20211103-Run16     GR00004421           COMPOUND
# 861161        source_9   20211103-Run16     GR00004421           COMPOUND
#
#        Metadata_Well Metadata_JCP2022            Metadata_InChIKey  \
# 0                A02   JCP2022_033924  IAZDPXIOMUYVGZ-UHFFFAOYSA-N
# 1                A03   JCP2022_085227  SRVFFFJZQVENJC-UHFFFAOYSA-N
# 2                A04   JCP2022_033924  IAZDPXIOMUYVGZ-UHFFFAOYSA-N
# 3                A05   JCP2022_036592  IPPYTNWGGOIMDZ-UHFFFAOYSA-N
# 4                A06   JCP2022_071885  PYZMXVUWLLQNEP-UHFFFAOYSA-N
# ...              ...              ...                          ...
# 861157           Z44   JCP2022_999999                          NaN
# 861158           Z45   JCP2022_999999                          NaN
# 861159           Z46   JCP2022_999999                          NaN
# 861160           Z47   JCP2022_033924  IAZDPXIOMUYVGZ-UHFFFAOYSA-N
# 861161           Z48   JCP2022_037716  IVUGFMLRJOCGAS-UHFFFAOYSA-N
#
#                                            Metadata_InChI  \
# 0                         InChI=1S/C2H6OS/c1-4(2)3/h1-2H3
# 1       InChI=1S/C17H30N2O5/c1-6-23-17(22)14-13(24-14)...
# 2                         InChI=1S/C2H6OS/c1-4(2)3/h1-2H3
# 3       InChI=1S/C17H12ClF3N4O2/c1-24(15-13(18)6-9(7-2...
# 4       InChI=1S/C10H7ClN4/c11-9-3-1-2-8(4-9)6-15-7-13...
# ...                                                   ...
# 861157                                                NaN
# 861158                                                NaN
# 861159                                                NaN
# 861160                    InChI=1S/C2H6OS/c1-4(2)3/h1-2H3
# 861161  InChI=1S/C28H21N7OS/c1-17-15-24(37-16-17)25-20...
#
#         Metadata_Sites_Per_Well           trt
# 0                             4  compound_neg
# 1                             4  compound_pos
# 2                             4  compound_neg
# 3                             4  compound_trt
# 4                             4  compound_trt
# ...                         ...           ...
# 861157                        4  compound_trt
# 861158                        4  compound_trt
# 861159                        4  compound_trt
# 861160                        4  compound_neg
# 861161                        4  compound_pos
#
# [861162 rows x 10 columns]

# %%
filtered_meta.to_csv(osp.join(metadata_path, "local_metadata.csv"), index=False)

# %%
q = (
    filtered_meta.assign(is_negative=lambda x: x.Metadata_JCP2022 == "JCP2022_033924")
    .groupby(["Metadata_Source", "Metadata_PlateType"])
    .agg(
        has_negatives=("is_negative", "sum"),
    )
)
q
# Out:
#                                     has_negatives
# Metadata_Source Metadata_PlateType
# source_1        COMPOUND                     9217
# source_10       COMPOUND                     6533
#                 TARGET2                       384
# source_11       COMPOUND                     7555
#                 TARGET2                       448
# source_13       CRISPR                       1128
#                 TARGET2                       414
# source_2        COMPOUND                    10877
#                 TARGET2                       649
# source_3        COMPOUND                     7574
#                 TARGET2                      1600
# source_4        ORF                             0
#                 TARGET1                       256
#                 TARGET2                      1408
# source_5        COMPOUND                     6304
#                 TARGET2                      1536
# source_6        COMPOUND                    12832
#                 TARGET2                      1366
# source_8        COMPOUND                     7776
#                 TARGET2                       256
# source_9        COMPOUND                    12672
#                 TARGET2                      2304

# %%
# Out:
#                                                     has_negatives
# Metadata_Source Metadata_Batch  Metadata_PlateType
# source_1        Batch1_20221004 COMPOUND                      768
#                 Batch2_20221006 COMPOUND                     1696
#                 Batch3_20221010 COMPOUND                     1605
#                 Batch4_20221012 COMPOUND                     1019
#                 Batch5_20221030 COMPOUND                     1473
# ...                                                           ...
# source_9        20211013-Run14  TARGET2                       256
#                 20211102-Run15  COMPOUND                     1280
#                                 TARGET2                       256
#                 20211103-Run16  COMPOUND                     2048
#                                 TARGET2                       256
#
# [236 rows x 1 columns]

# %%
df
# Out:
#         Metadata_Source              Metadata_Batch     Metadata_Plate  \
# 0             source_10  2021_05_31_U2OS_48_hr_run1  Dest210531-152149
# 1             source_10  2021_05_31_U2OS_48_hr_run1  Dest210531-152149
# 2             source_10  2021_05_31_U2OS_48_hr_run1  Dest210531-152149
# 3             source_10  2021_05_31_U2OS_48_hr_run1  Dest210531-152149
# 4             source_10  2021_05_31_U2OS_48_hr_run1  Dest210531-152149
# ...                 ...                         ...                ...
# 5121195        source_9              20211103-Run16         GR00004421
# 5121196        source_9              20211103-Run16         GR00004421
# 5121197        source_9              20211103-Run16         GR00004421
# 5121198        source_9              20211103-Run16         GR00004421
# 5121199        source_9              20211103-Run16         GR00004421
#
#         Metadata_Well  Metadata_Site  \
# 0                 A01              1
# 1                 A01              3
# 2                 A01              6
# 3                 A02              1
# 4                 A02              2
# ...               ...            ...
# 5121195           Z47              3
# 5121196           Z47              4
# 5121197           Z48              1
# 5121198           Z48              2
# 5121199           Z48              3
#
#                                           FileName_OrigAGP  \
# 0        /projects/cpjump3/jump/images/source_10/2021_0...
# 1        /projects/cpjump3/jump/images/source_10/2021_0...
# 2        /projects/cpjump3/jump/images/source_10/2021_0...
# 3        /projects/cpjump3/jump/images/source_10/2021_0...
# 4        /projects/cpjump3/jump/images/source_10/2021_0...
# ...                                                    ...
# 5121195  /projects/cpjump1/jump/images/source_9/2021110...
# 5121196  /projects/cpjump1/jump/images/source_9/2021110...
# 5121197  /projects/cpjump1/jump/images/source_9/2021110...
# 5121198  /projects/cpjump1/jump/images/source_9/2021110...
# 5121199  /projects/cpjump1/jump/images/source_9/2021110...
#
#                                           FileName_OrigDNA  \
# 0        /projects/cpjump3/jump/images/source_10/2021_0...
# 1        /projects/cpjump3/jump/images/source_10/2021_0...
# 2        /projects/cpjump3/jump/images/source_10/2021_0...
# 3        /projects/cpjump3/jump/images/source_10/2021_0...
# 4        /projects/cpjump3/jump/images/source_10/2021_0...
# ...                                                    ...
# 5121195  /projects/cpjump1/jump/images/source_9/2021110...
# 5121196  /projects/cpjump1/jump/images/source_9/2021110...
# 5121197  /projects/cpjump1/jump/images/source_9/2021110...
# 5121198  /projects/cpjump1/jump/images/source_9/2021110...
# 5121199  /projects/cpjump1/jump/images/source_9/2021110...
#
#                                            FileName_OrigER  \
# 0        /projects/cpjump3/jump/images/source_10/2021_0...
# 1        /projects/cpjump3/jump/images/source_10/2021_0...
# 2        /projects/cpjump3/jump/images/source_10/2021_0...
# 3        /projects/cpjump3/jump/images/source_10/2021_0...
# 4        /projects/cpjump3/jump/images/source_10/2021_0...
# ...                                                    ...
# 5121195  /projects/cpjump1/jump/images/source_9/2021110...
# 5121196  /projects/cpjump1/jump/images/source_9/2021110...
# 5121197  /projects/cpjump1/jump/images/source_9/2021110...
# 5121198  /projects/cpjump1/jump/images/source_9/2021110...
# 5121199  /projects/cpjump1/jump/images/source_9/2021110...
#
#                                          FileName_OrigMito  \
# 0        /projects/cpjump3/jump/images/source_10/2021_0...
# 1        /projects/cpjump3/jump/images/source_10/2021_0...
# 2        /projects/cpjump3/jump/images/source_10/2021_0...
# 3        /projects/cpjump3/jump/images/source_10/2021_0...
# 4        /projects/cpjump3/jump/images/source_10/2021_0...
# ...                                                    ...
# 5121195  /projects/cpjump1/jump/images/source_9/2021110...
# 5121196  /projects/cpjump1/jump/images/source_9/2021110...
# 5121197  /projects/cpjump1/jump/images/source_9/2021110...
# 5121198  /projects/cpjump1/jump/images/source_9/2021110...
# 5121199  /projects/cpjump1/jump/images/source_9/2021110...
#
#                                           FileName_OrigRNA
# 0        /projects/cpjump3/jump/images/source_10/2021_0...
# 1        /projects/cpjump3/jump/images/source_10/2021_0...
# 2        /projects/cpjump3/jump/images/source_10/2021_0...
# 3        /projects/cpjump3/jump/images/source_10/2021_0...
# 4        /projects/cpjump3/jump/images/source_10/2021_0...
# ...                                                    ...
# 5121195  /projects/cpjump1/jump/images/source_9/2021110...
# 5121196  /projects/cpjump1/jump/images/source_9/2021110...
# 5121197  /projects/cpjump1/jump/images/source_9/2021110...
# 5121198  /projects/cpjump1/jump/images/source_9/2021110...
# 5121199  /projects/cpjump1/jump/images/source_9/2021110...
#
# [5121200 rows x 10 columns]

# %%
df.merge(paw).groupby(["Metadata_Source", "Metadata_PlateType"]).FileName_OrigAGP.nunique()
# Out:
# Metadata_Source  Metadata_PlateType
# source_1         COMPOUND              296092
# source_10        COMPOUND              445602
#                  TARGET2                12660
# source_11        COMPOUND              360873
#                  TARGET2                14758
# source_13        CRISPR                305012
#                  TARGET2                12582
# source_2         COMPOUND              462180
#                  TARGET2                20964
# source_3         COMPOUND              507686
#                  TARGET2                52794
# source_4         ORF                   504138
#                  TARGET1                 8430
#                  TARGET2                46428
# source_5         COMPOUND              422356
#                  TARGET2                50676
# source_6         COMPOUND              472621
#                  TARGET2                44286
# source_8         COMPOUND              424116
#                  TARGET2                 8448
# source_9         COMPOUND              595512
#                  TARGET2                52986
# Name: FileName_OrigAGP, dtype: int64

# %%
52986 / 595512
# Out:
# 0.0889755370168863

# %%
unique_wells = df[["Metadata_Source", "Metadata_Batch", "Metadata_Plate", "Metadata_Well"]].drop_duplicates()

# %%
unique_wells
# Out:
#         Metadata_Source              Metadata_Batch     Metadata_Plate  \
# 0             source_10  2021_05_31_U2OS_48_hr_run1  Dest210531-152149
# 3             source_10  2021_05_31_U2OS_48_hr_run1  Dest210531-152149
# 7             source_10  2021_05_31_U2OS_48_hr_run1  Dest210531-152149
# 13            source_10  2021_05_31_U2OS_48_hr_run1  Dest210531-152149
# 19            source_10  2021_05_31_U2OS_48_hr_run1  Dest210531-152149
# ...                 ...                         ...                ...
# 5121181        source_9              20211103-Run16         GR00004421
# 5121185        source_9              20211103-Run16         GR00004421
# 5121189        source_9              20211103-Run16         GR00004421
# 5121193        source_9              20211103-Run16         GR00004421
# 5121197        source_9              20211103-Run16         GR00004421
#
#         Metadata_Well
# 0                 A01
# 3                 A02
# 7                 A03
# 13                A04
# 19                A05
# ...               ...
# 5121181           Z44
# 5121185           Z45
# 5121189           Z46
# 5121193           Z47
# 5121197           Z48
#
# [992234 rows x 4 columns]

# %%
df_wc = pd.merge(unique_wells, well_types, on=["Metadata_Source", "Metadata_Batch", "Metadata_Plate", "Metadata_Well"])

# %%
df_wc
# Out:
#        Metadata_Source              Metadata_Batch     Metadata_Plate  \
# 0            source_10  2021_05_31_U2OS_48_hr_run1  Dest210531-152149
# 1            source_10  2021_05_31_U2OS_48_hr_run1  Dest210531-152149
# 2            source_10  2021_05_31_U2OS_48_hr_run1  Dest210531-152149
# 3            source_10  2021_05_31_U2OS_48_hr_run1  Dest210531-152149
# 4            source_10  2021_05_31_U2OS_48_hr_run1  Dest210531-152149
# ...                ...                         ...                ...
# 992229        source_9              20211103-Run16         GR00004421
# 992230        source_9              20211103-Run16         GR00004421
# 992231        source_9              20211103-Run16         GR00004421
# 992232        source_9              20211103-Run16         GR00004421
# 992233        source_9              20211103-Run16         GR00004421
#
#        Metadata_Well Metadata_PlateType Metadata_JCP2022  \
# 0                A01           COMPOUND   JCP2022_085227
# 1                A02           COMPOUND   JCP2022_033924
# 2                A03           COMPOUND   JCP2022_056163
# 3                A04           COMPOUND   JCP2022_054175
# 4                A05           COMPOUND   JCP2022_999999
# ...              ...                ...              ...
# 992229           Z44           COMPOUND   JCP2022_999999
# 992230           Z45           COMPOUND   JCP2022_999999
# 992231           Z46           COMPOUND   JCP2022_999999
# 992232           Z47           COMPOUND   JCP2022_033924
# 992233           Z48           COMPOUND   JCP2022_037716
#
#         compound_negative_controls  compound_positive_controls  \
# 0                            False                        True
# 1                             True                       False
# 2                            False                       False
# 3                            False                       False
# 4                            False                       False
# ...                            ...                         ...
# 992229                       False                       False
# 992230                       False                       False
# 992231                       False                       False
# 992232                        True                       False
# 992233                       False                        True
#
#         compound_to_drop  orf_negative_controls  orf_positive_controls  \
# 0                  False                  False                  False
# 1                  False                  False                  False
# 2                  False                  False                  False
# 3                  False                  False                  False
# 4                  False                  False                  False
# ...                  ...                    ...                    ...
# 992229             False                  False                  False
# 992230             False                  False                  False
# 992231             False                  False                  False
# 992232             False                  False                  False
# 992233             False                  False                  False
#
#         orf_to_drop  crispr_positive_controls  crispr_negative_controls  \
# 0             False                     False                     False
# 1             False                     False                     False
# 2             False                     False                     False
# 3             False                     False                     False
# 4             False                     False                     False
# ...             ...                       ...                       ...
# 992229        False                     False                     False
# 992230        False                     False                     False
# 992231        False                     False                     False
# 992232        False                     False                     False
# 992233        False                     False                     False
#
#         crispr_to_drop  target_negative_controls  target_positive_controls  \
# 0                False                     False                     False
# 1                False                     False                     False
# 2                False                     False                     False
# 3                False                     False                     False
# 4                False                     False                     False
# ...                ...                       ...                       ...
# 992229           False                     False                     False
# 992230           False                     False                     False
# 992231           False                     False                     False
# 992232           False                     False                     False
# 992233           False                     False                     False
#
#         target_to_drop
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# ...                ...
# 992229           False
# 992230           False
# 992231           False
# 992232           False
# 992233           False
#
# [992234 rows x 18 columns]

# %%
q = (
    df_wc.groupby(["Metadata_Source", "Metadata_Batch", "Metadata_PlateType", "Metadata_Plate"])
    .agg(
        has_neg_compound=("compound_negative_controls", "sum"),
        has_neg_orf=("orf_negative_controls", "sum"),
        has_neg_crispr=("crispr_negative_controls", "sum"),
        has_neg_target=("target_negative_controls", "sum"),
        num_wells=("Metadata_Well", "nunique"),
    )
    .reset_index()
    .assign(has_neg=lambda x: x.has_neg_compound + x.has_neg_orf + x.has_neg_crispr + x.has_neg_target)
)
qq
# Out:
#      Metadata_Source   Metadata_Batch Metadata_PlateType Metadata_Plate  \
# 0           source_1  Batch1_20221004           COMPOUND       UL001641
# 1           source_1  Batch1_20221004           COMPOUND       UL001643
# 2           source_1  Batch1_20221004           COMPOUND       UL001645
# 3           source_1  Batch1_20221004           COMPOUND       UL001651
# 4           source_1  Batch1_20221004           COMPOUND       UL001653
# ...              ...              ...                ...            ...
# 2125        source_9   20211103-Run16           COMPOUND     GR00004418
# 2126        source_9   20211103-Run16           COMPOUND     GR00004419
# 2127        source_9   20211103-Run16           COMPOUND     GR00004420
# 2128        source_9   20211103-Run16           COMPOUND     GR00004421
# 2129        source_9   20211103-Run16            TARGET2     GR00004409
#
#       has_neg_compound  has_neg_orf  has_neg_crispr  has_neg_target  \
# 0                  128            0               0               0
# 1                  128            0               0               0
# 2                  128            0               0               0
# 3                  128            0               0               0
# 4                  128            0               0               0
# ...                ...          ...             ...             ...
# 2125               128            0               0               0
# 2126               128            0               0               0
# 2127               128            0               0               0
# 2128               128            0               0               0
# 2129                 0            0               0             256
#
#       num_wells  has_neg
# 0          1472      128
# 1          1472      128
# 2          1472      128
# 3          1472      128
# 4          1472      128
# ...         ...      ...
# 2125       1536      128
# 2126       1536      128
# 2127       1536      128
# 2128       1536      128
# 2129       1536      256
#
# [2130 rows x 10 columns]

# %%
qq = (
    well_types.groupby(["Metadata_Source", "Metadata_Batch", "Metadata_PlateType", "Metadata_Plate"])
    .agg(
        has_neg_compound=("compound_negative_controls", "sum"),
        has_neg_orf=("orf_negative_controls", "sum"),
        has_neg_crispr=("crispr_negative_controls", "sum"),
        has_neg_target=("target_negative_controls", "sum"),
        num_wells=("Metadata_Well", "nunique"),
    )
    .reset_index()
    .assign(has_neg=lambda x: x.has_neg_compound + x.has_neg_orf + x.has_neg_crispr + x.has_neg_target)
)
qq
# Out:
#      Metadata_Source   Metadata_Batch Metadata_PlateType Metadata_Plate  \
# 0           source_1  Batch1_20221004           COMPOUND       UL001641
# 1           source_1  Batch1_20221004           COMPOUND       UL001643
# 2           source_1  Batch1_20221004           COMPOUND       UL001645
# 3           source_1  Batch1_20221004           COMPOUND       UL001651
# 4           source_1  Batch1_20221004           COMPOUND       UL001653
# ...              ...              ...                ...            ...
# 2373        source_9   20211103-Run16           COMPOUND     GR00004418
# 2374        source_9   20211103-Run16           COMPOUND     GR00004419
# 2375        source_9   20211103-Run16           COMPOUND     GR00004420
# 2376        source_9   20211103-Run16           COMPOUND     GR00004421
# 2377        source_9   20211103-Run16            TARGET2     GR00004409
#
#       has_neg_compound  has_neg_orf  has_neg_crispr  has_neg_target  \
# 0                  128            0               0               0
# 1                  128            0               0               0
# 2                  128            0               0               0
# 3                  128            0               0               0
# 4                  128            0               0               0
# ...                ...          ...             ...             ...
# 2373               128            0               0               0
# 2374               128            0               0               0
# 2375               128            0               0               0
# 2376               128            0               0               0
# 2377                 0            0               0             256
#
#       num_wells  has_neg
# 0          1472      128
# 1          1472      128
# 2          1472      128
# 3          1472      128
# 4          1472      128
# ...         ...      ...
# 2373       1536      128
# 2374       1536      128
# 2375       1536      128
# 2376       1536      128
# 2377       1536      256
#
# [2378 rows x 10 columns]

# %%
(q.has_neg_compound > 0).sum() / q.shape[0]
# Out:
# 0.7530516431924883

# %%
(qqq.has_neg_compound > 0).sum() / qqq.shape[0]
# Out:
# 0.9981331673926571

# %%
qqq = q[q["Metadata_PlateType"] == "COMPOUND"]

# %%
(qqq.has_neg_compound < 20).sum()
# Out:
# 6

# %%
q["Metadata_PlateType"] == "COUMPOUND"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2125    False
# 2126    False
# 2127    False
# 2128    False
# 2129    False
# Name: Metadata_PlateType, Length: 2130, dtype: bool

# %%
paw.groupby("Metadata_Source")["Metadata_PlateType"].value_counts()
# Out:
# Metadata_Source  Metadata_PlateType
# source_1         COMPOUND               74843
#                  COMPOUND_EMPTY          5770
# source_10        COMPOUND               79862
#                  DMSO                    3071
#                  TARGET2                 2302
# source_11        COMPOUND               65663
#                  TARGET2                 2684
# source_13        CRISPR                 56832
#                  TARGET2                 2304
# source_2         COMPOUND               84032
#                  TARGET2                 3828
# source_3         COMPOUND               90929
#                  DMSO                   14591
#                  TARGET2                 9599
#                  COMPOUND_EMPTY          1152
# source_4         ORF                    96377
#                  TARGET2                 8442
#                  TARGET1                 1533
# source_5         COMPOUND               75646
#                  DMSO                   11904
#                  TARGET2                 9214
#                  POSCON8                 3072
# source_6         COMPOUND               86395
#                  TARGET2                 8064
# source_7         COMPOUND               46460
#                  TARGET2                 2688
# source_8         COMPOUND               76401
#                  COMPOUND_EMPTY          4992
#                  TARGET2                 1536
# source_9         COMPOUND              152064
#                  TARGET2                13824
# Name: count, dtype: int64

# %%
qq.query("has_neg == 0").Metadata_PlateType.value_counts()
# Out:
# Metadata_PlateType
# ORF         251
# CRISPR      148
# POSCON8       8
# COMPOUND      3
# Name: count, dtype: int64

# %%
q.groupby(["Metadata_Source", "Metadata_PlateType"]).Metadata_Plate.nunique()
# Out:
# Metadata_Source  Metadata_PlateType
# source_1         COMPOUND               51
# source_10        COMPOUND              208
#                  TARGET2                 6
# source_11        COMPOUND              172
#                  TARGET2                 7
# source_13        CRISPR                148
#                  TARGET2                 6
# source_2         COMPOUND              219
#                  TARGET2                10
# source_3         COMPOUND              237
#                  TARGET2                25
# source_4         ORF                   237
#                  TARGET1                 4
#                  TARGET2                22
# source_5         COMPOUND              197
#                  TARGET2                24
# source_6         COMPOUND              225
#                  TARGET2                21
# source_8         COMPOUND              199
#                  TARGET2                 4
# source_9         COMPOUND               99
#                  TARGET2                 9
# Name: Metadata_Plate, dtype: int64

# %%
q.query("has_neg == 0").head(10)
# Out:
#     Metadata_Source               Metadata_Batch Metadata_PlateType  \
# 137       source_10   2021_06_28_U2OS_48_hr_run9           COMPOUND
# 239       source_10  2021_08_23_U2OS_48_hr_run18           COMPOUND
# 240       source_10  2021_08_23_U2OS_48_hr_run18           COMPOUND
# 444       source_13                20220914_Run1             CRISPR
# 445       source_13                20220914_Run1             CRISPR
# 446       source_13                20220914_Run1             CRISPR
# 447       source_13                20220914_Run1             CRISPR
# 448       source_13                20220914_Run1             CRISPR
# 449       source_13                20220914_Run1             CRISPR
# 450       source_13                20220914_Run1             CRISPR
#
#         Metadata_Plate  has_neg_compound  has_neg_orf  has_neg_crispr  \
# 137  Dest210628-162003                 0            0               0
# 239  Dest210823-174240                 0            0               0
# 240  Dest210823-174422                 0            0               0
# 444       CP-CC9-R1-01                 0            0               0
# 445       CP-CC9-R1-02                 0            0               0
# 446       CP-CC9-R1-03                 0            0               0
# 447       CP-CC9-R1-04                 0            0               0
# 448       CP-CC9-R1-05                 0            0               0
# 449       CP-CC9-R1-06                 0            0               0
# 450       CP-CC9-R1-07                 0            0               0
#
#      has_neg_target  num_wells  has_neg
# 137               0        384        0
# 239               0        384        0
# 240               0        384        0
# 444               0        384        0
# 445               0        384        0
# 446               0        384        0
# 447               0        384        0
# 448               0        384        0
# 449               0        384        0
# 450               0        384        0
